# %%
import json
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag, map_tag
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('universal_tagset')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\MohammadJavad\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\MohammadJavad\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\MohammadJavad\AppData\Roaming\nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# True

# %%
with open('subtitle.json', encoding='utf-8') as f:
    data = json.load(f)

# %%
data[0]['text']
# Out:
# "I'm Eep. Of the Croods clan."

# %%
word_tokenize(data[0]['text'])
# Out:
# ['I', "'m", 'Eep', '.', 'Of', 'the', 'Croods', 'clan', '.']

# %%
def pos_tagger(item):
    text = nltk.word_tokenize(item['text'])
    posTagged = pos_tag(text)
    simplifiedTags = [(word, map_tag('en-ptb', 'universal', tag)) for word, tag in posTagged]
    return simplifiedTags

# %%
for item in data:
    tags = pos_tagger(item)
    item['word_tag'] = tags

# %%
data
# Out:
# [{'id': 1,
#   'startTime': 18.768,
#   'duration': 2.5410000000000004,
#   'endTime': 21.309,
#   'text': "I'm Eep. Of the Croods clan.",
#   'word_tag': [('I', 'PRON'),
#    ("'m", 'VERB'),
#    ('Eep', 'ADJ'),
#    ('.', '.'),
#    ('Of', 'ADP'),
#    ('the', 'DET'),
#    ('Croods', 'NOUN'),
#    ('clan', 'NOUN'),
#    ('.', '.')]},
#  {'id': 2,
#   'startTime': 24.983,
#   'duration': 1,
#   'endTime': 25.983,
#   'text': 'Gotcha!',
#   'word_tag': [('Gotcha', 'NOUN'), ('!', '.')]},
#  {'id': 3,
#   'startTime': 28.778,
#   'duration': 1.75,
#   'endTime': 30.528,
#   'text': "And I'm on the hunt.",
#   'word_tag': [('And', 'CONJ'),
#    ('I', 'PRON'),
#    ("'m", 'VERB'),
#    ('on', 'ADP'),
#    ('the', 'DET'),
#    ('hunt', 'NOUN'),
#    ('.', '.')]},
#  {'id': 4,
#   'startTime': 31.073,
#   'duration': 1.350999999999999,
#   'endTime': 32.424,
#   'text': 'But not for food.',
#   'word_tag': [('But', 'CONJ'),
#    ('not', 'ADV'),
#    ('for', 'ADP'),
#    ('food', 'NOUN'),
#    ('.', '.')]},
#  {'id': 5,
#   'startTime': 32.448,
#   'duration': 2.1310000000000002,
#   'endTime': 34.579,
#   'text': "That's old Eep. I'm new Eep.",
#   'word_tag': [('That', 'DET'),
#    ("'s", 'VERB'),
#    ('old', 'ADJ'),
#    ('Eep', 'NOUN'),
#    ('.', '.'),
#    ('I', 'PRON'),
#    ("'m", 'VERB'),
#    ('new', 'ADJ'),
#    ('Eep', 'NOUN'),
#    ('.', '.')]},
#  {'id': 6,
#   'startTime': 38.287,
#   'duration': 1.291000000000004,
#   'endTime': 39.578,
#   'text': 'Whoo!',
#   'word_tag': [('Whoo', 'NOUN'), ('!', '.')]},
#  {'id': 7,
#   'startTime': 43.71,
#   'duration': 1,
#   'endTime': 44.71,
#   'text': 'Ha!',
#   'word_tag': [('Ha', 'NOUN'), ('!', '.')]},
#  {'id': 8,
#   'startTime': 48.048,
#   'duration': 2.628999999999998,
#   'endTime': 50.677,
#   'text': 'And new Eep just needs a pen.',
#   'word_tag': [('And', 'CONJ'),
#    ('new', 'ADJ'),
#    ('Eep', 'NOUN'),
#    ('just', 'ADV'),
#    ('needs', 'VERB'),
#    ('a', 'DET'),
#    ('pen', 'NOUN'),
#    ('.', '.')]},
#  {'id': 9,
#   'startTime': 83.542,
#   'duration': 1.2270000000000039,
#   'endTime': 84.769,
#   'text': '‐ Dear Bark Journal,',
#   'word_tag': [('‐', 'ADJ'),
#    ('Dear', 'NOUN'),
#    ('Bark', 'NOUN'),
#    ('Journal', 'NOUN'),
#    (',', '.')]},
#  {'id': 10,
#   'startTime': 84.793,
#   'duration': 2.0619999999999976,
#   'endTime': 86.855,
#   'text': 'so what put the new in new me?',
#   'word_tag': [('so', 'ADV'),
#    ('what', 'PRON'),
#    ('put', 'VERB'),
#    ('the', 'DET'),
#    ('new', 'ADJ'),
#    ('in', 'ADP'),
#    ('new', 'ADJ'),
#    ('me', 'PRON'),
#    ('?', '.')]},
#  {'id': 11,
#   'startTime': 86.879,
#   'duration': 2.3519999999999897,
#   'endTime': 89.231,
#   'text': "I'm glad I asked myself that question.",
#   'word_tag': [('I', 'PRON'),
#    ("'m", 'VERB'),
#    ('glad', 'ADJ'),
#    ('I', 'PRON'),
#    ('asked', 'VERB'),
#    ('myself', 'PRON'),
#    ('that', 'ADP'),
#    ('question', 'NOUN'),
#    ('.', '.')]},
#  {'id': 12,
#   'startTime': 89.256,
#   'duration': 1.3109999999999928,
#   'endTime': 90.567,
#   'text': 'I was walking with my family,',
#   'word_tag': [('I', 'PRON'),
#    ('was', 'VERB'),
#    ('walking', 'VERB'),
#    ('with', 'ADP'),
#    ('my', 'PRON'),
#    ('family', 'NOUN'),
#    (',', '.')]},
#  {'id': 13,
#   'startTime': 90.591,
#   'duration': 1.6450000000000102,
#   'endTime': 92.236,
#   'text': 'my dad Grug, my mom Ugga,',
#   'word_tag': [('my', 'PRON'),
#    ('dad', 'ADJ'),
#    ('Grug', 'NOUN'),
#    (',', '.'),
#    ('my', 'PRON'),
#    ('mom', 'NOUN'),
#    ('Ugga', 'NOUN'),
#    (',', '.')]},
#  {'id': 14,
#   'startTime': 92.26,
#   'duration': 1.975999999999999,
#   'endTime': 94.236,
#   'text': 'my little brother Thunk, my little sister Sandy,',
#   'word_tag': [('my', 'PRON'),
#    ('little', 'ADJ'),
#    ('brother', 'NOUN'),
#    ('Thunk', 'NOUN'),
#    (',', '.'),
#    ('my', 'PRON'),
#    ('little', 'ADJ'),
#    ('sister', 'ADJ'),
#    ('Sandy', 'NOUN'),
#    (',', '.')]},
#  {'id': 15,
#   'startTime': 94.26,
#   'duration': 1.769999999999996,
#   'endTime': 96.03,
#   'text': 'my gran Gran, and Guy,',
#   'word_tag': [('my', 'PRON'),
#    ('gran', 'NOUN'),
#    ('Gran', 'NOUN'),
#    (',', '.'),
#    ('and', 'CONJ'),
#    ('Guy', 'NOUN'),
#    (',', '.')]},
#  {'id': 16,
#   'startTime': 96.054,
#   'duration': 3.3119999999999976,
#   'endTime': 99.366,
#   'text': 'as in my guy, the guy of my dreams but real.',
#   'word_tag': [('as', 'ADP'),
#    ('in', 'ADP'),
#    ('my', 'PRON'),
#    ('guy', 'NOUN'),
#    (',', '.'),
#    ('the', 'DET'),
#    ('guy', 'NOUN'),
#    ('of', 'ADP'),
#    ('my', 'PRON'),
#    ('dreams', 'NOUN'),
#    ('but', 'CONJ'),
#    ('real', 'ADJ'),
#    ('.', '.')]},
#  {'id': 17,
#   'startTime': 99.39,
#   'duration': 1.0190000000000055,
#   'endTime': 100.409,
#   'text': 'And we hit a wall.',
#   'word_tag': [('And', 'CONJ'),
#    ('we', 'PRON'),
#    ('hit', 'VERB'),
#    ('a', 'DET'),
#    ('wall', 'NOUN'),
#    ('.', '.')]},
#  {'id': 18,
#   'startTime': 100.433,
#   'duration': 1.4369999999999976,
#   'endTime': 101.87,
#   'text': 'So, of course, Dad smashed through it.',
#   'word_tag': [('So', 'ADV'),
#    (',', '.'),
#    ('of', 'ADP'),
#    ('course', 'NOUN'),
#    (',', '.'),
#    ('Dad', 'NOUN'),
#    ('smashed', 'VERB'),
#    ('through', 'ADP'),
#    ('it', 'PRON'),
#    ('.', '.')]},
#  {'id': 19,
#   'startTime': 101.894,
#   'duration': 1.4369999999999976,
#   'endTime': 103.331,
#   'text': 'And there was a farm and a tree house.',
#   'word_tag': [('And', 'CONJ'),
#    ('there', 'DET'),
#    ('was', 'VERB'),
#    ('a', 'DET'),
#    ('farm', 'NOUN'),
#    ('and', 'CONJ'),
#    ('a', 'DET'),
#    ('tree', 'ADJ'),
#    ('house', 'NOUN'),
#    ('.', '.')]},
#  {'id': 20,
#   'startTime': 103.354,
#   'duration': 2.774000000000001,
#   'endTime': 106.128,
#   'text': 'And a family, the Bettermans, Phil, Hope and their daughter Dawn.',
#   'word_tag': [('And', 'CONJ'),
#    ('a', 'DET'),
#    ('family', 'NOUN'),
#    (',', '.'),
#    ('the', 'DET'),
#    ('Bettermans', 'NOUN'),
#    (',', '.'),
#    ('Phil', 'NOUN'),
#    (',', '.'),
#    ('Hope', 'NOUN'),
#    ('and', 'CONJ'),
#    ('their', 'PRON'),
#    ('daughter', 'NOUN'),
#    ('Dawn', 'NOUN'),
#    ('.', '.')]},
#  {'id': 21,
#   'startTime': 106.152,
#   'duration': 2.5360000000000014,
#   'endTime': 108.688,
#   'text': "They weren't happy about their wall, and we didn't get along.",
#   'word_tag': [('They', 'PRON'),
#    ('were', 'VERB'),
#    ("n't", 'ADV'),
#    ('happy', 'ADJ'),
#    ('about', 'ADP'),
#    ('their', 'PRON'),
#    ('wall', 'NOUN'),
#    (',', '.'),
#    ('and', 'CONJ'),
#    ('we', 'PRON'),
#    ('did', 'VERB'),
#    ("n't", 'ADV'),
#    ('get', 'VERB'),
#    ('along', 'ADV'),
#    ('.', '.')]},
#  {'id': 22,
#   'startTime': 109.234,
#   'duration': 2.1030000000000086,
#   'endTime': 111.337,
#   'text': 'But then we were attacked by these crazy punch monkeys',
#   'word_tag': [('But', 'CONJ'),
#    ('then', 'ADV'),
#    ('we', 'PRON'),
#    ('were', 'VERB'),
#    ('attacked', 'VERB'),
#    ('by', 'ADP'),
#    ('these', 'DET'),
#    ('crazy', 'ADJ'),
#    ('punch', 'NOUN'),
#    ('monkeys', 'NOUN')]},
#  {'id': 23,
#   'startTime': 111.36,
#   'duration': 1.3170000000000073,
#   'endTime': 112.677,
#   'text': 'so we had to team up to survive.',
#   'word_tag': [('so', 'ADP'),
#    ('we', 'PRON'),
#    ('had', 'VERB'),
#    ('to', 'PRT'),
#    ('team', 'VERB'),
#    ('up', 'ADV'),
#    ('to', 'PRT'),
#    ('survive', 'VERB'),
#    ('.', '.')]},
#  {'id': 24,
#   'startTime': 112.701,
#   'duration': 2.848000000000013,
#   'endTime': 115.549,
#   'text': 'It went so well, the Bettermans invited us to move in,',
#   'word_tag': [('It', 'PRON'),
#    ('went', 'VERB'),
#    ('so', 'ADV'),
#    ('well', 'ADV'),
#    (',', '.'),
#    ('the', 'DET'),
#    ('Bettermans', 'NOUN'),
#    ('invited', 'VERB'),
#    ('us', 'PRON'),
#    ('to', 'PRT'),
#    ('move', 'VERB'),
#    ('in', 'ADP'),
#    (',', '.')]},
#  {'id': 25,
#   'startTime': 115.573,
#   'duration': 1.936000000000007,
#   'endTime': 117.509,
#   'text': 'and, boom, first neighborhood ever!',
#   'word_tag': [('and', 'CONJ'),
#    (',', '.'),
#    ('boom', 'NOUN'),
#    (',', '.'),
#    ('first', 'ADV'),
#    ('neighborhood', 'ADJ'),
#    ('ever', 'ADV'),
#    ('!', '.')]},
#  {'id': 26,
#   'startTime': 117.533,
#   'duration': 1.7780000000000058,
#   'endTime': 119.311,
#   'text': 'And, boom, again, first best friend ever!',
#   'word_tag': [('And', 'CONJ'),
#    (',', '.'),
#    ('boom', 'NOUN'),
#    (',', '.'),
#    ('again', 'ADV'),
#    (',', '.'),
#    ('first', 'ADV'),
#    ('best', 'ADJ'),
#    ('friend', 'NOUN'),
#    ('ever', 'ADV'),
#    ('!', '.')]},
#  {'id': 27,
#   'startTime': 119.335,
#   'duration': 1.01100000000001,
#   'endTime': 120.346,
#   'text': 'Dawn rocks!',
#   'word_tag': [('Dawn', 'NOUN'), ('rocks', 'NOUN'), ('!', '.')]},
#  {'id': 28,
#   'startTime': 120.37,
#   'duration': 1.1850000000000023,
#   'endTime': 121.555,
#   'text': "But the punch monkeys don't,",
#   'word_tag': [('But', 'CONJ'),
#    ('the', 'DET'),
#    ('punch', 'NOUN'),
#    ('monkeys', 'NOUN'),
#    ('do', 'VERB'),
#    ("n't", 'ADV'),
#    (',', '.')]},
#  {'id': 29,
#   'startTime': 121.579,
#   'duration': 2.437000000000012,
#   'endTime': 124.016,
#   'text': 'so welcome back, wall, and hello, peace and quiet.',
#   'word_tag': [('so', 'ADV'),
#    ('welcome', 'ADJ'),
#    ('back', 'ADV'),
#    (',', '.'),
#    ('wall', 'NOUN'),
#    (',', '.'),
#    ('and', 'CONJ'),
#    ('hello', 'NOUN'),
#    (',', '.'),
#    ('peace', 'NOUN'),
#    ('and', 'CONJ'),
#    ('quiet', 'ADJ'),
#    ('.', '.')]},
#  {'id': 30,
#   'startTime': 124.04,
#   'duration': 2.228999999999999,
#   'endTime': 126.269,
#   'text': "Yep, the Croods are livin' easy now.",
#   'word_tag': [('Yep', 'NOUN'),
#    (',', '.'),
#    ('the', 'DET'),
#    ('Croods', 'NOUN'),
#    ('are', 'VERB'),
#    ('livin', 'ADJ'),
#    ("'", 'PRT'),
#    ('easy', 'ADJ'),
#    ('now', 'ADV'),
#    ('.', '.')]},
#  {'id': 31,
#   'startTime': 126.293,
#   'duration': 1.8400000000000034,
#   'endTime': 128.133,
#   'text': "Except it's not so easy.",
#   'word_tag': [('Except', 'ADP'),
#    ('it', 'PRON'),
#    ("'s", 'VERB'),
#    ('not', 'ADV'),
#    ('so', 'ADV'),
#    ('easy', 'ADJ'),
#    ('.', '.')]},
#  {'id': 32,
#   'startTime': 132.174,
#   'duration': 1.7690000000000055,
#   'endTime': 133.943,
#   'text': '‐ Is it night yet?',
#   'word_tag': [('‐', 'NOUN'),
#    ('Is', 'VERB'),
#    ('it', 'PRON'),
#    ('night', 'NOUN'),
#    ('yet', 'ADV'),
#    ('?', '.')]},
#  {'id': 33,
#   'startTime': 133.967,
#   'duration': 1.9359999999999786,
#   'endTime': 135.903,
#   'text': '‐ No, honey, we just woke up.',
#   'word_tag': [('‐', 'NOUN'),
#    ('No', 'NOUN'),
#    (',', '.'),
#    ('honey', 'NOUN'),
#    (',', '.'),
#    ('we', 'PRON'),
#    ('just', 'ADV'),
#    ('woke', 'VERB'),
#    ('up', 'PRT'),
#    ('.', '.')]},
#  {'id': 34,
#   'startTime': 135.927,
#   'duration': 1.6030000000000086,
#   'endTime': 137.53,
#   'text': '‐ Aw, come on!',
#   'word_tag': [('‐', 'NOUN'),
#    ('Aw', 'NOUN'),
#    (',', '.'),
#    ('come', 'VERB'),
#    ('on', 'ADP'),
#    ('!', '.')]},
#  {'id': 35,
#   'startTime': 137.554,
#   'duration': 2.561000000000007,
#   'endTime': 140.115,
#   'text': 'No hunting, no chasing.',
#   'word_tag': [('No', 'DET'),
#    ('hunting', 'NOUN'),
#    (',', '.'),
#    ('no', 'DET'),
#    ('chasing', 'NOUN'),
#    ('.', '.')]},
#  {'id': 36,
#   'startTime': 140.139,
#   'duration': 1.2099999999999795,
#   'endTime': 141.349,
#   'text': '‐ No fighting.',
#   'word_tag': [('‐', 'ADJ'), ('No', 'DET'), ('fighting', 'NOUN'), ('.', '.')]},
#  {'id': 37,
#   'startTime': 143.1,
#   'duration': 1.1059999999999945,
#   'endTime': 144.206,
#   'text': '‐ Sorry, Sandy.',
#   'word_tag': [('‐', 'NOUN'),
#    ('Sorry', 'NOUN'),
#    (',', '.'),
#    ('Sandy', 'NOUN'),
#    ('.', '.')]},
#  {'id': 38,
#   'startTime': 144.23,
#   'duration': 1.1430000000000007,
#   'endTime': 145.373,
#   'text': 'Nothing to fight here.',
#   'word_tag': [('Nothing', 'NOUN'),
#    ('to', 'PRT'),
#    ('fight', 'VERB'),
#    ('here', 'ADV'),
#    ('.', '.')]},
#  {'id': 39,
#   'startTime': 145.397,
#   'duration': 2.4339999999999975,
#   'endTime': 147.831,
#   'text': 'The farm has food, shelter, and safety.',
#   'word_tag': [('The', 'DET'),
#    ('farm', 'NOUN'),
#    ('has', 'VERB'),
#    ('food', 'NOUN'),
#    (',', '.'),
#    ('shelter', 'NOUN'),
#    (',', '.'),
#    ('and', 'CONJ'),
#    ('safety', 'NOUN'),
#    ('.', '.')]},
#  {'id': 40,
#   'startTime': 147.855,
#   'duration': 1.8540000000000134,
#   'endTime': 149.709,
#   'text': "It's comfortable, predictable‐‐",
#   'word_tag': [('It', 'PRON'),
#    ("'s", 'VERB'),
#    ('comfortable', 'ADJ'),
#    (',', '.'),
#    ('predictable‐‐', 'NOUN')]},
#  {'id': 41,
#   'startTime': 149.733,
#   'duration': 2.7280000000000086,
#   'endTime': 152.461,
#   'text': '‐ And so‐o‐o‐o boring!',
#   'word_tag': [('‐', 'NOUN'),
#    ('And', 'CONJ'),
#    ('so‐o‐o‐o', 'NOUN'),
#    ('boring', 'NOUN'),
#    ('!', '.')]},
#  {'id': 42,
#   'startTime': 152.485,
#   'duration': 1.893999999999977,
#   'endTime': 154.379,
#   'text': '‐ Relaxing?',
#   'word_tag': [('‐', 'NOUN'), ('Relaxing', 'NOUN'), ('?', '.')]},
#  {'id': 43,
#   'startTime': 154.403,
#   'duration': 1.771000000000015,
#   'endTime': 156.174,
#   'text': 'Good. Keep doing that.',
#   'word_tag': [('Good', 'ADJ'),
#    ('.', '.'),
#    ('Keep', 'VERB'),
#    ('doing', 'VERB'),
#    ('that', 'DET'),
#    ('.', '.')]},
#  {'id': 44,
#   'startTime': 156.198,
#   'duration': 1.6020000000000039,
#   'endTime': 157.8,
#   'text': '‐ Can we help with anything, Hope?',
#   'word_tag': [('‐', 'NOUN'),
#    ('Can', 'VERB'),
#    ('we', 'PRON'),
#    ('help', 'VERB'),
#    ('with', 'ADP'),
#    ('anything', 'NOUN'),
#    (',', '.'),
#    ('Hope', 'NOUN'),
#    ('?', '.')]},
#  {'id': 45,
#   'startTime': 157.824,
#   'duration': 2.35299999999998,
#   'endTime': 160.177,
#   'text': "‐ Nope. Everything's taken care of.",
#   'word_tag': [('‐', 'ADJ'),
#    ('Nope', 'NOUN'),
#    ('.', '.'),
#    ('Everything', 'NOUN'),
#    ("'s", 'PRT'),
#    ('taken', 'VERB'),
#    ('care', 'NOUN'),
#    ('of', 'ADP'),
#    ('.', '.')]},
#  {'id': 46,
#   'startTime': 160.201,
#   'duration': 1.8950000000000102,
#   'endTime': 162.096,
#   'text': 'Ew!',
#   'word_tag': [('Ew', 'NOUN'), ('!', '.')]},
#  {'id': 47,
#   'startTime': 162.12,
#   'duration': 1.8530000000000086,
#   'endTime': 163.973,
#   'text': "So I'll make lunch",
#   'word_tag': [('So', 'ADV'),
#    ('I', 'PRON'),
#    ("'ll", 'VERB'),
#    ('make', 'VERB'),
#    ('lunch', 'NOUN')]},
#  {'id': 48,
#   'startTime': 163.997,
#   'duration': 1.6019999999999754,
#   'endTime': 165.599,
#   'text': 'and you stay out of the way and do nothing.',
#   'word_tag': [('and', 'CONJ'),
#    ('you', 'PRON'),
#    ('stay', 'VERB'),
#    ('out', 'ADP'),
#    ('of', 'ADP'),
#    ('the', 'DET'),
#    ('way', 'NOUN'),
#    ('and', 'CONJ'),
#    ('do', 'VERB'),
#    ('nothing', 'NOUN'),
#    ('.', '.')]},
#  {'id': 49,
#   'startTime': 165.623,
#   'duration': 0.818000000000012,
#   'endTime': 166.441,
#   'text': 'Bye!',
#   'word_tag': [('Bye', 'NOUN'), ('!', '.')]},
#  {'id': 50,
#   'startTime': 166.465,
#   'duration': 1.3460000000000036,
#   'endTime': 167.811,
#   'text': '‐ Do nothing?',
#   'word_tag': [('‐', 'NOUN'),
#    ('Do', 'VERB'),
#    ('nothing', 'NOUN'),
#    ('?', '.')]},
#  {'id': 51,
#   'startTime': 167.835,
#   'duration': 1.1850000000000023,
#   'endTime': 169.02,
#   'text': "We're the Croods!",
#   'word_tag': [('We', 'PRON'),
#    ("'re", 'VERB'),
#    ('the', 'DET'),
#    ('Croods', 'NOUN'),
#    ('!', '.')]},
#  {'id': 52,
#   'startTime': 169.043,
#   'duration': 1.5269999999999868,
#   'endTime': 170.57,
#   'text': 'We hunt Kangadillos.',
#   'word_tag': [('We', 'PRON'),
#    ('hunt', 'VERB'),
#    ('Kangadillos', 'NOUN'),
#    ('.', '.')]},
#  {'id': 53,
#   'startTime': 170.594,
#   'duration': 1.5529999999999973,
#   'endTime': 172.147,
#   'text': 'We topple trees.',
#   'word_tag': [('We', 'PRON'),
#    ('topple', 'VERB'),
#    ('trees', 'NOUN'),
#    ('.', '.')]},
#  {'id': 54,
#   'startTime': 172.171,
#   'duration': 1.8559999999999945,
#   'endTime': 174.027,
#   'text': 'We paint the things we do on rocks.',
#   'word_tag': [('We', 'PRON'),
#    ('paint', 'VERB'),
#    ('the', 'DET'),
#    ('things', 'NOUN'),
#    ('we', 'PRON'),
#    ('do', 'VERB'),
#    ('on', 'ADP'),
#    ('rocks', 'NOUN'),
#    ('.', '.')]},
#  {'id': 55,
#   'startTime': 174.051,
#   'duration': 2.0180000000000007,
#   'endTime': 176.069,
#   'text': 'We gotta have a purpose on this farm.',
#   'word_tag': [('We', 'PRON'),
#    ('got', 'VERB'),
#    ('ta', 'NOUN'),
#    ('have', 'VERB'),
#    ('a', 'DET'),
#    ('purpose', 'NOUN'),
#    ('on', 'ADP'),
#    ('this', 'DET'),
#    ('farm', 'NOUN'),
#    ('.', '.')]},
#  {'id': 56,
#   'startTime': 176.093,
#   'duration': 3.4860000000000184,
#   'endTime': 179.579,
#   'text': "Because, if we don't, we're as useless as a slugopotamus.",
#   'word_tag': [('Because', 'ADP'),
#    (',', '.'),
#    ('if', 'ADP'),
#    ('we', 'PRON'),
#    ('do', 'VERB'),
#    ("n't", 'ADV'),
#    (',', '.'),
#    ('we', 'PRON'),
#    ("'re", 'VERB'),
#    ('as', 'ADV'),
#    ('useless', 'ADJ'),
#    ('as', 'ADP'),
#    ('a', 'DET'),
#    ('slugopotamus', 'NOUN'),
#    ('.', '.')]},
#  {'id': 57,
#   'startTime': 179.603,
#   'duration': 2.679000000000002,
#   'endTime': 182.282,
#   'text': "And the Croods aren't slugopotomuses.",
#   'word_tag': [('And', 'CONJ'),
#    ('the', 'DET'),
#    ('Croods', 'NOUN'),
#    ('are', 'VERB'),
#    ("n't", 'ADV'),
#    ('slugopotomuses', 'NOUN'),
#    ('.', '.')]},
#  {'id': 58,
#   'startTime': 182.306,
#   'duration': 1.1479999999999961,
#   'endTime': 183.454,
#   'text': '‐ As far as we know.',
#   'word_tag': [('‐', 'NOUN'),
#    ('As', 'ADV'),
#    ('far', 'ADV'),
#    ('as', 'ADP'),
#    ('we', 'PRON'),
#    ('know', 'VERB'),
#    ('.', '.')]},
#  {'id': 59,
#   'startTime': 183.478,
#   'duration': 2.2249999999999943,
#   'endTime': 185.703,
#   'text': '‐ Is doing nothing really so bad?',
#   'word_tag': [('‐', 'NOUN'),
#    ('Is', 'VERB'),
#    ('doing', 'VERB'),
#    ('nothing', 'NOUN'),
#    ('really', 'ADV'),
#    ('so', 'ADV'),
#    ('bad', 'ADJ'),
#    ('?', '.')]},
#  {'id': 60,
#   'startTime': 185.727,
#   'duration': 1.5,
#   'endTime': 187.227,
#   'text': 'Look how happy Douglas is.',
#   'word_tag': [('Look', 'VERB'),
#    ('how', 'ADV'),
#    ('happy', 'ADJ'),
#    ('Douglas', 'NOUN'),
#    ('is', 'VERB'),
#    ('.', '.')]},
#  {'id': 61,
#   'startTime': 188.396,
#   'duration': 2.8130000000000166,
#   'endTime': 191.209,
#   'text': "See? I've always said moving is overrated.",
#   'word_tag': [('See', 'VERB'),
#    ('?', '.'),
#    ('I', 'PRON'),
#    ("'ve", 'VERB'),
#    ('always', 'ADV'),
#    ('said', 'VERB'),
#    ('moving', 'NOUN'),
#    ('is', 'VERB'),
#    ('overrated', 'VERB'),
#    ('.', '.')]},
#  {'id': 62,
#   'startTime': 191.233,
#   'duration': 3.6869999999999834,
#   'endTime': 194.92,
#   'text': 'Oh, uh, could someone move my cup closer to my mouth?',
#   'word_tag': [('Oh', 'X'),
#    (',', '.'),
#    ('uh', 'X'),
#    (',', '.'),
#    ('could', 'VERB'),
#    ('someone', 'NOUN'),
#    ('move', 'VERB'),
#    ('my', 'PRON'),
#    ('cup', 'NOUN'),
#    ('closer', 'NOUN'),
#    ('to', 'PRT'),
#    ('my', 'PRON'),
#    ('mouth', 'NOUN'),
#    ('?', '.')]},
#  {'id': 63,
#   'startTime': 194.944,
#   'duration': 1.3120000000000118,
#   'endTime': 196.256,
#   'text': "‐ Thunk's right.",
#   'word_tag': [('‐', 'ADJ'),
#    ('Thunk', 'NOUN'),
#    ("'s", 'PRT'),
#    ('right', 'NOUN'),
#    ('.', '.')]},
#  {'id': 64,
#   'startTime': 196.28,
#   'duration': 1.436000000000007,
#   'endTime': 197.716,
#   'text': 'Down time has an upside.',
#   'word_tag': [('Down', 'NOUN'),
#    ('time', 'NOUN'),
#    ('has', 'VERB'),
#    ('an', 'DET'),
#    ('upside', 'NOUN'),
#    ('.', '.')]},
#  {'id': 65,
#   'startTime': 197.74,
#   'duration': 2.377999999999986,
#   'endTime': 200.118,
#   'text': 'More time for stolen kisses.',
#   'word_tag': [('More', 'ADJ'),
#    ('time', 'NOUN'),
#    ('for', 'ADP'),
#    ('stolen', 'ADJ'),
#    ('kisses', 'NOUN'),
#    ('.', '.')]},
#  {'id': 66,
#   'startTime': 201.409,
#   'duration': 1.170000000000016,
#   'endTime': 202.579,
#   'text': '‐ Morning, Guy.',
#   'word_tag': [('‐', 'ADJ'),
#    ('Morning', 'NOUN'),
#    (',', '.'),
#    ('Guy', 'NOUN'),
#    ('.', '.')]},
#  {'id': 67,
#   'startTime': 206.956,
#   'duration': 2.980000000000018,
#   'endTime': 209.936,
#   'text': '‐ More time for careless whispers. Whoops.',
#   'word_tag': [('‐', 'ADV'),
#    ('More', 'ADJ'),
#    ('time', 'NOUN'),
#    ('for', 'ADP'),
#    ('careless', 'ADJ'),
#    ('whispers', 'NOUN'),
#    ('.', '.'),
#    ('Whoops', 'NOUN'),
#    ('.', '.')]},
#  {'id': 68,
#   'startTime': 209.96,
#   'duration': 1.9359999999999786,
#   'endTime': 211.896,
#   'text': '‐ Hmm. More time for cuddling.',
#   'word_tag': [('‐', 'ADJ'),
#    ('Hmm', 'NOUN'),
#    ('.', '.'),
#    ('More', 'ADJ'),
#    ('time', 'NOUN'),
#    ('for', 'ADP'),
#    ('cuddling', 'VERB'),
#    ('.', '.')]},
#  {'id': 69,
#   'startTime': 211.92,
#   'duration': 1.5180000000000007,
#   'endTime': 213.438,
#   'text': '‐ No. No time for cuddling.',
#   'word_tag': [('‐', 'ADJ'),
#    ('No', 'NOUN'),
#    ('.', '.'),
#    ('No', 'DET'),
#    ('time', 'NOUN'),
#    ('for', 'ADP'),
#    ('cuddling', 'VERB'),
#    ('.', '.')]},
#  {'id': 70,
#   'startTime': 213.462,
#   'duration': 1.4870000000000232,
#   'endTime': 214.949,
#   'text': '‐ Wh... What about the sleep pile?',
#   'word_tag': [('‐', 'NOUN'),
#    ('Wh', 'NOUN'),
#    ('...', '.'),
#    ('What', 'PRON'),
#    ('about', 'ADP'),
#    ('the', 'DET'),
#    ('sleep', 'NOUN'),
#    ('pile', 'NOUN'),
#    ('?', '.')]},
#  {'id': 71,
#   'startTime': 214.973,
#   'duration': 1.8219999999999743,
#   'endTime': 216.795,
#   'text': 'We did that every night in our old life.',
#   'word_tag': [('We', 'PRON'),
#    ('did', 'VERB'),
#    ('that', 'ADP'),
#    ('every', 'DET'),
#    ('night', 'NOUN'),
#    ('in', 'ADP'),
#    ('our', 'PRON'),
#    ('old', 'ADJ'),
#    ('life', 'NOUN'),
#    ('.', '.')]},
#  {'id': 72,
#   'startTime': 220.012,
#   'duration': 1.3100000000000023,
#   'endTime': 221.322,
#   'text': "‐ That's family cuddling.",
#   'word_tag': [('‐', 'NOUN'),
#    ('That', 'DET'),
#    ("'s", 'VERB'),
#    ('family', 'NOUN'),
#    ('cuddling', 'NOUN'),
#    ('.', '.')]},
#  {'id': 73,
#   'startTime': 221.346,
#   'duration': 1.1020000000000039,
#   'endTime': 222.448,
#   'text': "It's completely different.",
#   'word_tag': [('It', 'PRON'),
#    ("'s", 'VERB'),
#    ('completely', 'ADV'),
#    ('different', 'ADJ'),
#    ('.', '.')]},
#  {'id': 74,
#   'startTime': 222.472,
#   'duration': 3.353999999999985,
#   'endTime': 225.826,
#   'text': '‐ Fine. New Eep and Guy can cuddle with our eyes.',
#   'word_tag': [('‐', 'ADJ'),
#    ('Fine', 'NOUN'),
#    ('.', '.'),
#    ('New', 'NOUN'),
#    ('Eep', 'NOUN'),
#    ('and', 'CONJ'),
#    ('Guy', 'NOUN'),
#    ('can', 'VERB'),
#    ('cuddle', 'VERB'),
#    ('with', 'ADP'),
#    ('our', 'PRON'),
#    ('eyes', 'NOUN'),
#    ('.', '.')]},
#  {'id': 75,
#   'startTime': 225.85,
#   'duration': 1.3530000000000086,
#   'endTime': 227.203,
#   'text': '‐ Hey. ‐ Hey.',
#   'word_tag': [('‐', 'NOUN'),
#    ('Hey', 'NOUN'),
#    ('.', '.'),
#    ('‐', 'NOUN'),
#    ('Hey', 'NOUN'),
#    ('.', '.')]},
#  {'id': 76,
#   'startTime': 227.227,
#   'duration': 1.1020000000000039,
#   'endTime': 228.329,
#   'text': '‐ Hey!',
#   'word_tag': [('‐', 'NOUN'), ('Hey', 'NOUN'), ('!', '.')]},
#  {'id': 77,
#   'startTime': 228.353,
#   'duration': 2.258999999999986,
#   'endTime': 230.612,
#   'text': '‐ Hey! Something to do just ran by.',
#   'word_tag': [('‐', 'NOUN'),
#    ('Hey', 'NOUN'),
#    ('!', '.'),
#    ('Something', 'VERB'),
#    ('to', 'PRT'),
#    ('do', 'VERB'),
#    ('just', 'ADV'),
#    ('ran', 'VERB'),
#    ('by', 'ADP'),
#    ('.', '.')]},
#  {'id': 78,
#   'startTime': 231.439,
#   'duration': 0.561000000000007,
#   'endTime': 232,
#   'text': "Mom's right.",
#   'word_tag': [('Mom', 'NOUN'), ("'s", 'PRT'), ('right', 'NOUN'), ('.', '.')]},
#  {'id': 79,
#   'startTime': 232.024,
#   'duration': 1.1459999999999866,
#   'endTime': 233.17,
#   'text': 'Pigator on the loose.',
#   'word_tag': [('Pigator', 'NOUN'),
#    ('on', 'ADP'),
#    ('the', 'DET'),
#    ('loose', 'NOUN'),
#    ('.', '.')]},
#  {'id': 80,
#   'startTime': 233.194,
#   'duration': 2.183000000000021,
#   'endTime': 235.377,
#   'text': "‐ Let's grab it and stab it!",
#   'word_tag': [('‐', 'ADJ'),
#    ('Let', 'NOUN'),
#    ("'s", 'PRT'),
#    ('grab', 'NOUN'),
#    ('it', 'PRON'),
#    ('and', 'CONJ'),
#    ('stab', 'VERB'),
#    ('it', 'PRON'),
#    ('!', '.')]},
#  {'id': 81,
#   'startTime': 235.401,
#   'duration': 3.9879999999999995,
#   'endTime': 239.389,
#   'text': '‐ Or, we can redirect that stabbing energy into something less stabby.',
#   'word_tag': [('‐', 'NOUN'),
#    ('Or', 'CONJ'),
#    (',', '.'),
#    ('we', 'PRON'),
#    ('can', 'VERB'),
#    ('redirect', 'VERB'),
#    ('that', 'ADP'),
#    ('stabbing', 'VERB'),
#    ('energy', 'NOUN'),
#    ('into', 'ADP'),
#    ('something', 'NOUN'),
#    ('less', 'ADJ'),
#    ('stabby', 'NOUN'),
#    ('.', '.')]},
#  {'id': 82,
#   'startTime': 239.413,
#   'duration': 3.7819999999999823,
#   'endTime': 243.195,
#   'text': "‐ Uh, I'm still waiting for someone to move my cup. Yeah.",
#   'word_tag': [('‐', 'NOUN'),
#    ('Uh', 'NOUN'),
#    (',', '.'),
#    ('I', 'PRON'),
#    ("'m", 'VERB'),
#    ('still', 'ADV'),
#    ('waiting', 'VERB'),
#    ('for', 'ADP'),
#    ('someone', 'NOUN'),
#    ('to', 'PRT'),
#    ('move', 'VERB'),
#    ('my', 'PRON'),
#    ('cup', 'NOUN'),
#    ('.', '.'),
#    ('Yeah', 'X'),
#    ('.', '.')]},
#  {'id': 83,
#   'startTime': 269.728,
#   'duration': 1,
#   'endTime': 270.728,
#   'text': '‐ Ooh!',
#   'word_tag': [('‐', 'ADJ'), ('Ooh', 'NOUN'), ('!', '.')]},
#  {'id': 84,
#   'startTime': 272.021,
#   'duration': 1.8959999999999582,
#   'endTime': 273.917,
#   'text': '‐ Aw!',
#   'word_tag': [('‐', 'ADJ'), ('Aw', 'NOUN'), ('!', '.')]},
#  {'id': 85,
#   'startTime': 273.941,
#   'duration': 0.8570000000000277,
#   'endTime': 274.798,
#   'text': 'Morning, Phil.',
#   'word_tag': [('Morning', 'NOUN'), (',', '.'), ('Phil', 'NOUN'), ('.', '.')]},
#  {'id': 86,
#   'startTime': 274.822,
#   'duration': 1.0120000000000005,
#   'endTime': 275.834,
#   'text': '‐ Good morning.',
#   'word_tag': [('‐', 'ADV'),
#    ('Good', 'ADJ'),
#    ('morning', 'NOUN'),
#    ('.', '.')]},
#  {'id': 87,
#   'startTime': 275.858,
#   'duration': 1.8120000000000118,
#   'endTime': 277.67,
#   'text': 'Just testing my new trap.',
#   'word_tag': [('Just', 'ADV'),
#    ('testing', 'VERB'),
#    ('my', 'PRON'),
#    ('new', 'ADJ'),
#    ('trap', 'NOUN'),
#    ('.', '.')]},
#  {'id': 88,
#   'startTime': 277.694,
#   'duration': 2.4359999999999786,
#   'endTime': 280.13,
#   'text': 'So no more runaway pigators.',
#   'word_tag': [('So', 'ADV'),
#    ('no', 'ADV'),
#    ('more', 'ADJ'),
#    ('runaway', 'ADJ'),
#    ('pigators', 'NOUN'),
#    ('.', '.')]},
#  {'id': 89,
#   'startTime': 280.154,
#   'duration': 1.896000000000015,
#   'endTime': 282.05,
#   'text': '‐ But we were gonna catch that pigator.',
#   'word_tag': [('‐', 'NOUN'),
#    ('But', 'CONJ'),
#    ('we', 'PRON'),
#    ('were', 'VERB'),
#    ('gon', 'VERB'),
#    ('na', 'PRT'),
#    ('catch', 'VERB'),
#    ('that', 'DET'),
#    ('pigator', 'NOUN'),
#    ('.', '.')]},
#  {'id': 90,
#   'startTime': 282.074,
#   'duration': 2.2690000000000055,
#   'endTime': 284.343,
#   'text': '‐ No need. This trap is flawless.',
#   'word_tag': [('‐', 'NOUN'),
#    ('No', 'DET'),
#    ('need', 'NOUN'),
#    ('.', '.'),
#    ('This', 'DET'),
#    ('trap', 'NOUN'),
#    ('is', 'VERB'),
#    ('flawless', 'ADJ'),
#    ('.', '.')]},
#  {'id': 91,
#   'startTime': 284.367,
#   'duration': 2.3109999999999786,
#   'endTime': 286.678,
#   'text': 'Just like the rest of the system that runs this farm.',
#   'word_tag': [('Just', 'ADV'),
#    ('like', 'ADP'),
#    ('the', 'DET'),
#    ('rest', 'NOUN'),
#    ('of', 'ADP'),
#    ('the', 'DET'),
#    ('system', 'NOUN'),
#    ('that', 'DET'),
#    ('runs', 'VERB'),
#    ('this', 'DET'),
#    ('farm', 'NOUN'),
#    ('.', '.')]},
#  {'id': 92,
#   'startTime': 286.702,
#   'duration': 2.437000000000012,
#   'endTime': 289.139,
#   'text': 'So keep doing nothing, Croods.',
#   'word_tag': [('So', 'ADV'),
#    ('keep', 'ADJ'),
#    ('doing', 'VERB'),
#    ('nothing', 'NOUN'),
#    (',', '.'),
#    ('Croods', 'NOUN'),
#    ('.', '.')]},
#  {'id': 93,
#   'startTime': 289.163,
#   'duration': 1.6030000000000086,
#   'endTime': 290.766,
#   'text': 'It suits you.',
#   'word_tag': [('It', 'PRON'),
#    ('suits', 'NOUN'),
#    ('you', 'PRON'),
#    ('.', '.')]},
#  {'id': 94,
#   'startTime': 290.79,
#   'duration': 0.6469999999999914,
#   'endTime': 291.437,
#   'text': '‐ What was that?',
#   'word_tag': [('‐', 'VERB'),
#    ('What', 'PRON'),
#    ('was', 'VERB'),
#    ('that', 'DET'),
#    ('?', '.')]},
#  {'id': 95,
#   'startTime': 291.461,
#   'duration': 1.7239999999999895,
#   'endTime': 293.185,
#   'text': "‐ Oh, that's a bounceberry.",
#   'word_tag': [('‐', 'NOUN'),
#    ('Oh', 'X'),
#    (',', '.'),
#    ('that', 'DET'),
#    ("'s", 'VERB'),
#    ('a', 'DET'),
#    ('bounceberry', 'NOUN'),
#    ('.', '.')]},
#  {'id': 96,
#   'startTime': 293.209,
#   'duration': 1.5670000000000073,
#   'endTime': 294.776,
#   'text': "They're ripe. It's time to harvest them.",
#   'word_tag': [('They', 'PRON'),
#    ("'re", 'VERB'),
#    ('ripe', 'ADJ'),
#    ('.', '.'),
#    ('It', 'PRON'),
#    ("'s", 'VERB'),
#    ('time', 'NOUN'),
#    ('to', 'PRT'),
#    ('harvest', 'VERB'),
#    ('them', 'PRON'),
#    ('.', '.')]},
#  {'id': 97,
#   'startTime': 294.8,
#   'duration': 1.26400000000001,
#   'endTime': 296.064,
#   'text': "‐ Ooh! Uh, we'll do that!",
#   'word_tag': [('‐', 'ADJ'),
#    ('Ooh', 'NOUN'),
#    ('!', '.'),
#    ('Uh', 'NOUN'),
#    (',', '.'),
#    ('we', 'PRON'),
#    ("'ll", 'VERB'),
#    ('do', 'VERB'),
#    ('that', 'DET'),
#    ('!', '.')]},
#  {'id': 98,
#   'startTime': 296.088,
#   'duration': 1.5179999999999723,
#   'endTime': 297.606,
#   'text': "‐ Oh, I don't think so.",
#   'word_tag': [('‐', 'NOUN'),
#    ('Oh', 'NOUN'),
#    (',', '.'),
#    ('I', 'PRON'),
#    ('do', 'VERB'),
#    ("n't", 'ADV'),
#    ('think', 'VERB'),
#    ('so', 'ADV'),
#    ('.', '.')]},
#  {'id': 99,
#   'startTime': 297.63,
#   'duration': 2.566000000000031,
#   'endTime': 300.196,
#   'text': 'Bounceberries are a favorite fruit around here.',
#   'word_tag': [('Bounceberries', 'NOUN'),
#    ('are', 'VERB'),
#    ('a', 'DET'),
#    ('favorite', 'ADJ'),
#    ('fruit', 'NOUN'),
#    ('around', 'ADP'),
#    ('here', 'ADV'),
#    ('.', '.')]},
#  {'id': 100,
#   'startTime': 300.22,
#   'duration': 2.5579999999999927,
#   'endTime': 302.778,
#   'text': 'And they can be tricky. Even dangerous.',
#   'word_tag': [('And', 'CONJ'),
#    ('they', 'PRON'),
#    ('can', 'VERB'),
#    ('be', 'VERB'),
#    ('tricky', 'ADJ'),
#    ('.', '.'),
#    ('Even', 'ADV'),
#    ('dangerous', 'ADJ'),
#    ('.', '.')]},
#  {'id': 101,
#   'startTime': 302.802,
#   'duration': 1.9839999999999804,
#   'endTime': 304.786,
#   'text': "‐ Great! We love danger. We're in.",
#   'word_tag': [('‐', 'ADV'),
#    ('Great', 'NOUN'),
#    ('!', '.'),
#    ('We', 'PRON'),
#    ('love', 'VERB'),
#    ('danger', 'ADV'),
#    ('.', '.'),
#    ('We', 'PRON'),
#    ("'re", 'VERB'),
#    ('in', 'ADP'),
#    ('.', '.')]},
#  {'id': 102,
#   'startTime': 304.81,
#   'duration': 1.5960000000000036,
#   'endTime': 306.406,
#   'text': "‐ You're out. It's taken care of.",
#   'word_tag': [('‐', 'NOUN'),
#    ('You', 'PRON'),
#    ("'re", 'VERB'),
#    ('out', 'PRT'),
#    ('.', '.'),
#    ('It', 'PRON'),
#    ("'s", 'VERB'),
#    ('taken', 'VERB'),
#    ('care', 'NOUN'),
#    ('of', 'ADP'),
#    ('.', '.')]},
#  {'id': 103,
#   'startTime': 306.43,
#   'duration': 2.355000000000018,
#   'endTime': 308.785,
#   'text': '‐ Uh, let me guess. By the system?',
#   'word_tag': [('‐', 'NOUN'),
#    ('Uh', 'NOUN'),
#    (',', '.'),
#    ('let', 'VERB'),
#    ('me', 'PRON'),
#    ('guess', 'VERB'),
#    ('.', '.'),
#    ('By', 'ADP'),
#    ('the', 'DET'),
#    ('system', 'NOUN'),
#    ('?', '.')]},
#  {'id': 104,
#   'startTime': 308.809,
#   'duration': 2.5609999999999786,
#   'endTime': 311.37,
#   'text': '‐ Precisely. With me at the helm.',
#   'word_tag': [('‐', 'NOUN'),
#    ('Precisely', 'ADV'),
#    ('.', '.'),
#    ('With', 'ADP'),
#    ('me', 'PRON'),
#    ('at', 'ADP'),
#    ('the', 'DET'),
#    ('helm', 'NOUN'),
#    ('.', '.')]},
#  {'id': 105,
#   'startTime': 311.394,
#   'duration': 3.6890000000000214,
#   'endTime': 315.083,
#   'text': "So, if you'll excuse me, I need to limber up before the harvest.",
#   'word_tag': [('So', 'ADV'),
#    (',', '.'),
#    ('if', 'ADP'),
#    ('you', 'PRON'),
#    ("'ll", 'VERB'),
#    ('excuse', 'VERB'),
#    ('me', 'PRON'),
#    (',', '.'),
#    ('I', 'PRON'),
#    ('need', 'VERB'),
#    ('to', 'PRT'),
#    ('limber', 'VERB'),
#    ('up', 'PRT'),
#    ('before', 'ADP'),
#    ('the', 'DET'),
#    ('harvest', 'NOUN'),
#    ('.', '.')]},
#  {'id': 106,
#   'startTime': 315.106,
#   'duration': 2.7110000000000127,
#   'endTime': 317.817,
#   'text': 'Time for a steam in the man cave.',
#   'word_tag': [('Time', 'NOUN'),
#    ('for', 'ADP'),
#    ('a', 'DET'),
#    ('steam', 'NOUN'),
#    ('in', 'ADP'),
#    ('the', 'DET'),
#    ('man', 'NOUN'),
#    ('cave', 'NOUN'),
#    ('.', '.')]},
#  {'id': 107,
#   'startTime': 319.735,
#   'duration': 0.9379999999999882,
#   'endTime': 320.673,
#   'text': '‐ Come on.',
#   'word_tag': [('‐', 'ADJ'), ('Come', 'NOUN'), ('on', 'ADP'), ('.', '.')]},
#  {'id': 108,
#   'startTime': 320.697,
#   'duration': 2.5190000000000055,
#   'endTime': 323.216,
#   'text': 'There has to be something we can do around here',
#   'word_tag': [('There', 'DET'),
#    ('has', 'VERB'),
#    ('to', 'PRT'),
#    ('be', 'VERB'),
#    ('something', 'NOUN'),
#    ('we', 'PRON'),
#    ('can', 'VERB'),
#    ('do', 'VERB'),
#    ('around', 'ADV'),
#    ('here', 'ADV')]},
#  {'id': 109,
#   'startTime': 323.24,
#   'duration': 1.9780000000000086,
#   'endTime': 325.218,
#   'text': '‐ You know who has ideas?',
#   'word_tag': [('‐', 'NOUN'),
#    ('You', 'PRON'),
#    ('know', 'VERB'),
#    ('who', 'PRON'),
#    ('has', 'VERB'),
#    ('ideas', 'NOUN'),
#    ('?', '.')]},
#  {'id': 110,
#   'startTime': 325.242,
#   'duration': 2.4359999999999786,
#   'endTime': 327.678,
#   'text': 'Guy‐Boy, I can hear those wheels turning.',
#   'word_tag': [('Guy‐Boy', 'NOUN'),
#    (',', '.'),
#    ('I', 'PRON'),
#    ('can', 'VERB'),
#    ('hear', 'VERB'),
#    ('those', 'DET'),
#    ('wheels', 'NOUN'),
#    ('turning', 'VERB'),
#    ('.', '.')]},
#  {'id': 111,
#   'startTime': 327.702,
#   'duration': 1.4780000000000086,
#   'endTime': 329.18,
#   'text': '‐ You get one pet name a day.',
#   'word_tag': [('‐', 'NOUN'),
#    ('You', 'PRON'),
#    ('get', 'VERB'),
#    ('one', 'NUM'),
#    ('pet', 'NOUN'),
#    ('name', 'NOUN'),
#    ('a', 'DET'),
#    ('day', 'NOUN'),
#    ('.', '.')]},
#  {'id': 112,
#   'startTime': 329.204,
#   'duration': 1.6850000000000023,
#   'endTime': 330.889,
#   'text': "So that's it. You're done.",
#   'word_tag': [('So', 'ADP'),
#    ('that', 'DET'),
#    ("'s", 'VERB'),
#    ('it', 'PRON'),
#    ('.', '.'),
#    ('You', 'PRON'),
#    ("'re", 'VERB'),
#    ('done', 'VERB'),
#    ('.', '.')]},
#  {'id': 113,
#   'startTime': 330.913,
#   'duration': 3.1469999999999914,
#   'endTime': 334.06,
#   'text': '‐ Well, one idea is both sides compromise and live in peace.',
#   'word_tag': [('‐', 'ADV'),
#    ('Well', 'ADV'),
#    (',', '.'),
#    ('one', 'NUM'),
#    ('idea', 'NOUN'),
#    ('is', 'VERB'),
#    ('both', 'DET'),
#    ('sides', 'NOUN'),
#    ('compromise', 'NOUN'),
#    ('and', 'CONJ'),
#    ('live', 'VERB'),
#    ('in', 'ADP'),
#    ('peace', 'NOUN'),
#    ('.', '.')]},
#  {'id': 114,
#   'startTime': 334.084,
#   'duration': 1.6850000000000023,
#   'endTime': 335.769,
#   'text': "‐ Ha. That'll never work.",
#   'word_tag': [('‐', 'ADJ'),
#    ('Ha', 'NOUN'),
#    ('.', '.'),
#    ('That', 'DET'),
#    ("'ll", 'VERB'),
#    ('never', 'ADV'),
#    ('work', 'VERB'),
#    ('.', '.')]},
#  {'id': 115,
#   'startTime': 335.793,
#   'duration': 2.3149999999999977,
#   'endTime': 338.108,
#   'text': '‐ You just need something to do to be happy.',
#   'word_tag': [('‐', 'NOUN'),
#    ('You', 'PRON'),
#    ('just', 'ADV'),
#    ('need', 'VERB'),
#    ('something', 'NOUN'),
#    ('to', 'PRT'),
#    ('do', 'VERB'),
#    ('to', 'PRT'),
#    ('be', 'VERB'),
#    ('happy', 'ADJ'),
#    ('.', '.')]},
#  {'id': 116,
#   'startTime': 338.132,
#   'duration': 2.1030000000000086,
#   'endTime': 340.235,
#   'text': "But it doesn't have to be work, right?",
#   'word_tag': [('But', 'CONJ'),
#    ('it', 'PRON'),
#    ('does', 'VERB'),
#    ("n't", 'ADV'),
#    ('have', 'VERB'),
#    ('to', 'PRT'),
#    ('be', 'VERB'),
#    ('work', 'NOUN'),
#    (',', '.'),
#    ('right', 'ADV'),
#    ('?', '.')]},
#  {'id': 117,
#   'startTime': 340.259,
#   'duration': 1.0989999999999895,
#   'endTime': 341.358,
#   'text': 'So, how about a game?',
#   'word_tag': [('So', 'ADV'),
#    (',', '.'),
#    ('how', 'ADV'),
#    ('about', 'ADP'),
#    ('a', 'DET'),
#    ('game', 'NOUN'),
#    ('?', '.')]},
#  {'id': 118,
#   'startTime': 341.382,
#   'duration': 1.274000000000001,
#   'endTime': 342.656,
#   'text': 'Ooh. How about this,',
#   'word_tag': [('Ooh', 'NOUN'),
#    ('.', '.'),
#    ('How', 'ADV'),
#    ('about', 'ADP'),
#    ('this', 'DET'),
#    (',', '.')]},
#  {'id': 119,
#   'startTime': 342.68,
#   'duration': 2.2860000000000014,
#   'endTime': 344.966,
#   'text': 'you find something and then you throw it?',
#   'word_tag': [('you', 'PRON'),
#    ('find', 'VERB'),
#    ('something', 'NOUN'),
#    ('and', 'CONJ'),
#    ('then', 'ADV'),
#    ('you', 'PRON'),
#    ('throw', 'VERB'),
#    ('it', 'PRON'),
#    ('?', '.')]},
#  {'id': 120,
#   'startTime': 348.014,
#   'duration': 1.1200000000000045,
#   'endTime': 349.134,
#   'text': 'It\'s called "Throw."',
#   'word_tag': [('It', 'PRON'),
#    ("'s", 'VERB'),
#    ('called', 'VERB'),
#    ('``', '.'),
#    ('Throw', 'NOUN'),
#    ('.', '.'),
#    ("''", '.')]},
#  {'id': 121,
#   'startTime': 351.268,
#   'duration': 1.8560000000000514,
#   'endTime': 353.124,
#   'text': 'Yeah. Throw might need some work.',
#   'word_tag': [('Yeah', 'X'),
#    ('.', '.'),
#    ('Throw', 'VERB'),
#    ('might', 'VERB'),
#    ('need', 'VERB'),
#    ('some', 'DET'),
#    ('work', 'NOUN'),
#    ('.', '.')]},
#  {'id': 122,
#   'startTime': 353.148,
#   'duration': 1.0559999999999832,
#   'endTime': 354.204,
#   'text': '‐ Better idea,',
#   'word_tag': [('‐', 'ADV'),
#    ('Better', 'NOUN'),
#    ('idea', 'NOUN'),
#    (',', '.')]},
#  {'id': 123,
#   'startTime': 354.228,
#   'duration': 1.9370000000000118,
#   'endTime': 356.165,
#   'text': 'we stop doing what Phil and Hope tell us to do',
#   'word_tag': [('we', 'PRON'),
#    ('stop', 'VERB'),
#    ('doing', 'VERB'),
#    ('what', 'PRON'),
#    ('Phil', 'NOUN'),
#    ('and', 'CONJ'),
#    ('Hope', 'NOUN'),
#    ('tell', 'VERB'),
#    ('us', 'PRON'),
#    ('to', 'PRT'),
#    ('do', 'VERB')]},
#  {'id': 124,
#   'startTime': 356.189,
#   'duration': 1.7699999999999818,
#   'endTime': 357.959,
#   'text': 'and we start doing what we wanna do.',
#   'word_tag': [('and', 'CONJ'),
#    ('we', 'PRON'),
#    ('start', 'VERB'),
#    ('doing', 'VERB'),
#    ('what', 'PRON'),
#    ('we', 'PRON'),
#    ('wan', 'VERB'),
#    ('na', 'ADV'),
#    ('do', 'VERB'),
#    ('.', '.')]},
#  {'id': 125,
#   'startTime': 357.983,
#   'duration': 1.225999999999999,
#   'endTime': 359.209,
#   'text': 'Because this is our home now.',
#   'word_tag': [('Because', 'ADP'),
#    ('this', 'DET'),
#    ('is', 'VERB'),
#    ('our', 'PRON'),
#    ('home', 'NOUN'),
#    ('now', 'ADV'),
#    ('.', '.')]},
#  {'id': 126,
#   'startTime': 359.233,
#   'duration': 0.6469999999999914,
#   'endTime': 359.88,
#   'text': '‐ Yes.',
#   'word_tag': [('‐', 'ADJ'), ('Yes', 'NOUN'), ('.', '.')]},
#  {'id': 127,
#   'startTime': 359.904,
#   'duration': 2.184000000000026,
#   'endTime': 362.088,
#   'text': "‐ Grug, go tell Phil that's what's happening.",
#   'word_tag': [('‐', 'ADJ'),
#    ('Grug', 'NOUN'),
#    (',', '.'),
#    ('go', 'VERB'),
#    ('tell', 'ADV'),
#    ('Phil', 'NOUN'),
#    ('that', 'DET'),
#    ("'s", 'VERB'),
#    ('what', 'PRON'),
#    ("'s", 'VERB'),
#    ('happening', 'VERB'),
#    ('.', '.')]},
#  {'id': 128,
#   'startTime': 362.112,
#   'duration': 1.5609999999999786,
#   'endTime': 363.673,
#   'text': '‐ Aw, in the steam?',
#   'word_tag': [('‐', 'NOUN'),
#    ('Aw', 'NOUN'),
#    (',', '.'),
#    ('in', 'ADP'),
#    ('the', 'DET'),
#    ('steam', 'NOUN'),
#    ('?', '.')]},
#  {'id': 129,
#   'startTime': 363.697,
#   'duration': 2.437000000000012,
#   'endTime': 366.134,
#   'text': "‐ Yes. And I'll tell Hope I'm gonna help her.",
#   'word_tag': [('‐', 'ADJ'),
#    ('Yes', 'NOUN'),
#    ('.', '.'),
#    ('And', 'CONJ'),
#    ('I', 'PRON'),
#    ("'ll", 'VERB'),
#    ('tell', 'VERB'),
#    ('Hope', 'NOUN'),
#    ('I', 'PRON'),
#    ("'m", 'VERB'),
#    ('gon', 'VERB'),
#    ('na', 'PRT'),
#    ('help', 'VERB'),
#    ('her', 'PRON'),
#    ('.', '.')]},
#  {'id': 130,
#   'startTime': 366.158,
#   'duration': 1.0600000000000023,
#   'endTime': 367.218,
#   'text': 'Whether she likes it or not.',
#   'word_tag': [('Whether', 'ADP'),
#    ('she', 'PRON'),
#    ('likes', 'VERB'),
#    ('it', 'PRON'),
#    ('or', 'CONJ'),
#    ('not', 'ADV'),
#    ('.', '.')]},
#  {'id': 131,
#   'startTime': 367.242,
#   'duration': 1.4780000000000086,
#   'endTime': 368.72,
#   'text': '‐ Dawn will love this.',
#   'word_tag': [('‐', 'ADJ'),
#    ('Dawn', 'NOUN'),
#    ('will', 'VERB'),
#    ('love', 'VERB'),
#    ('this', 'DET'),
#    ('.', '.')]},
#  {'id': 132,
#   'startTime': 368.744,
#   'duration': 2.603999999999985,
#   'endTime': 371.348,
#   'text': 'Her whole life, her parents have been so worried about her getting hurt,',
#   'word_tag': [('Her', 'PRON'),
#    ('whole', 'ADJ'),
#    ('life', 'NOUN'),
#    (',', '.'),
#    ('her', 'PRON'),
#    ('parents', 'NOUN'),
#    ('have', 'VERB'),
#    ('been', 'VERB'),
#    ('so', 'ADV'),
#    ('worried', 'ADJ'),
#    ('about', 'ADP'),
#    ('her', 'PRON'),
#    ('getting', 'VERB'),
#    ('hurt', 'NOUN'),
#    (',', '.')]},
#  {'id': 133,
#   'startTime': 371.372,
#   'duration': 1.5649999999999977,
#   'endTime': 372.937,
#   'text': "they've never let her do anything.",
#   'word_tag': [('they', 'PRON'),
#    ("'ve", 'VERB'),
#    ('never', 'ADV'),
#    ('let', 'VERB'),
#    ('her', 'PRON'),
#    ('do', 'VERB'),
#    ('anything', 'NOUN'),
#    ('.', '.')]},
#  {'id': 134,
#   'startTime': 372.961,
#   'duration': 1.38900000000001,
#   'endTime': 374.35,
#   'text': "Let's go, Guy‐baby.",
#   'word_tag': [('Let', 'VERB'),
#    ("'s", 'PRT'),
#    ('go', 'VERB'),
#    (',', '.'),
#    ('Guy‐baby', 'NOUN'),
#    ('.', '.')]},
#  {'id': 135,
#   'startTime': 374.374,
#   'duration': 2.3389999999999986,
#   'endTime': 376.713,
#   'text': "‐ One pet name a day. That's two.",
#   'word_tag': [('‐', 'VERB'),
#    ('One', 'NUM'),
#    ('pet', 'NOUN'),
#    ('name', 'NOUN'),
#    ('a', 'DET'),
#    ('day', 'NOUN'),
#    ('.', '.'),
#    ('That', 'DET'),
#    ("'s", 'VERB'),
#    ('two', 'NUM'),
#    ('.', '.')]},
#  {'id': 136,
#   'startTime': 382.382,
#   'duration': 3.480000000000018,
#   'endTime': 385.862,
#   'text': "‐ You're always welcome in my man cave, Grug.",
#   'word_tag': [('‐', 'NOUN'),
#    ('You', 'PRON'),
#    ("'re", 'VERB'),
#    ('always', 'ADV'),
#    ('welcome', 'ADJ'),
#    ('in', 'ADP'),
#    ('my', 'PRON'),
#    ('man', 'NOUN'),
#    ('cave', 'NOUN'),
#    (',', '.'),
#    ('Grug', 'NOUN'),
#    ('.', '.')]},
#  {'id': 137,
#   'startTime': 385.886,
#   'duration': 2.394999999999982,
#   'endTime': 388.281,
#   'text': 'My steam is your steam.',
#   'word_tag': [('My', 'PRON'),
#    ('steam', 'NOUN'),
#    ('is', 'VERB'),
#    ('your', 'PRON'),
#    ('steam', 'NOUN'),
#    ('.', '.')]},
#  {'id': 138,
#   'startTime': 388.305,
#   'duration': 1.225999999999999,
#   'endTime': 389.531,
#   'text': '‐ Uh, yeah, thanks.',
#   'word_tag': [('‐', 'NOUN'),
#    ('Uh', 'NOUN'),
#    (',', '.'),
#    ('yeah', 'X'),
#    (',', '.'),
#    ('thanks', 'NOUN'),
#    ('.', '.')]},
#  {'id': 139,
#   'startTime': 389.555,
#   'duration': 1.670000000000016,
#   'endTime': 391.225,
#   'text': "So I'm here to tell you‐‐",
#   'word_tag': [('So', 'ADV'),
#    ('I', 'PRON'),
#    ("'m", 'VERB'),
#    ('here', 'ADV'),
#    ('to', 'PRT'),
#    ('tell', 'VERB'),
#    ('you‐‐', 'NOUN')]},
#  {'id': 140,
#   'startTime': 396.103,
#   'duration': 1.0500000000000114,
#   'endTime': 397.153,
#   'text': "So I'm here to‐‐",
#   'word_tag': [('So', 'ADV'),
#    ('I', 'PRON'),
#    ("'m", 'VERB'),
#    ('here', 'ADV'),
#    ('to‐‐', 'NOUN')]},
#  {'id': 141,
#   'startTime': 406.447,
#   'duration': 1.920000000000016,
#   'endTime': 408.367,
#   'text': "I'm here to tell you things‐‐",
#   'word_tag': [('I', 'PRON'),
#    ("'m", 'VERB'),
#    ('here', 'ADV'),
#    ('to', 'PRT'),
#    ('tell', 'VERB'),
#    ('you', 'PRON'),
#    ('things‐‐', 'VERB')]},
#  {'id': 142,
#   'startTime': 409.201,
#   'duration': 1.5190000000000055,
#   'endTime': 410.72,
#   'text': 'are going to change around here.',
#   'word_tag': [('are', 'VERB'),
#    ('going', 'VERB'),
#    ('to', 'PRT'),
#    ('change', 'VERB'),
#    ('around', 'ADP'),
#    ('here', 'ADV'),
#    ('.', '.')]},
#  {'id': 143,
#   'startTime': 410.744,
#   'duration': 1.1859999999999786,
#   'endTime': 411.93,
#   'text': '‐ Of course.',
#   'word_tag': [('‐', 'NOUN'), ('Of', 'ADP'), ('course', 'NOUN'), ('.', '.')]},
#  {'id': 144,
#   'startTime': 411.954,
#   'duration': 1.483000000000004,
#   'endTime': 413.437,
#   'text': "Let's talk about that.",
#   'word_tag': [('Let', 'VERB'),
#    ("'s", 'PRT'),
#    ('talk', 'VERB'),
#    ('about', 'ADP'),
#    ('that', 'DET'),
#    ('.', '.')]},
#  {'id': 145,
#   'startTime': 413.461,
#   'duration': 1.5960000000000036,
#   'endTime': 415.057,
#   'text': "‐ Great, so we're gonna‐‐",
#   'word_tag': [('‐', 'ADV'),
#    ('Great', 'NOUN'),
#    (',', '.'),
#    ('so', 'ADP'),
#    ('we', 'PRON'),
#    ("'re", 'VERB'),
#    ('gon', 'VERB'),
#    ('na', 'PRT'),
#    ('‐‐', 'VERB')]},
#  {'id': 146,
#   'startTime': 415.081,
#   'duration': 1.5190000000000055,
#   'endTime': 416.6,
#   'text': '‐ After the steam.',
#   'word_tag': [('‐', 'NOUN'),
#    ('After', 'ADP'),
#    ('the', 'DET'),
#    ('steam', 'NOUN'),
#    ('.', '.')]},
#  {'id': 147,
#   'startTime': 416.625,
#   'duration': 1.3100000000000023,
#   'endTime': 417.935,
#   'text': '‐ Right, but‐but Ugga said‐‐',
#   'word_tag': [('‐', 'ADV'),
#    ('Right', 'NOUN'),
#    (',', '.'),
#    ('but‐but', 'NOUN'),
#    ('Ugga', 'NOUN'),
#    ('said‐‐', 'NOUN')]},
#  {'id': 148,
#   'startTime': 417.959,
#   'duration': 1.6870000000000118,
#   'endTime': 419.646,
#   'text': '‐ Steam first, talk after.',
#   'word_tag': [('‐', 'NOUN'),
#    ('Steam', 'NOUN'),
#    ('first', 'ADV'),
#    (',', '.'),
#    ('talk', 'NOUN'),
#    ('after', 'ADP'),
#    ('.', '.')]},
#  {'id': 149,
#   'startTime': 419.67,
#   'duration': 1.475999999999999,
#   'endTime': 421.146,
#   'text': "‐ Okay, but, uh, I'm‐‐",
#   'word_tag': [('‐', 'NOUN'),
#    ('Okay', 'NOUN'),
#    (',', '.'),
#    ('but', 'CONJ'),
#    (',', '.'),
#    ('uh', 'X'),
#    (',', '.'),
#    ("I'm‐‐", 'NOUN')]},
#  {'id': 150,
#   'startTime': 421.17,
#   'duration': 1.853999999999985,
#   'endTime': 423.024,
#   'text': '‐ Steam, then talk.',
#   'word_tag': [('‐', 'ADJ'),
#    ('Steam', 'NOUN'),
#    (',', '.'),
#    ('then', 'ADV'),
#    ('talk', 'NOUN'),
#    ('.', '.')]},
#  {'id': 151,
#   'startTime': 423.048,
#   'duration': 0.5169999999999959,
#   'endTime': 423.565,
#   'text': '‐ But‐‐',
#   'word_tag': [('‐', 'NOUN'), ('But‐‐', 'NOUN')]},
#  {'id': 152,
#   'startTime': 423.589,
#   'duration': 1.0400000000000205,
#   'endTime': 424.629,
#   'text': '‐ Steam, talk.',
#   'word_tag': [('‐', 'ADJ'),
#    ('Steam', 'NOUN'),
#    (',', '.'),
#    ('talk', 'NOUN'),
#    ('.', '.')]},
#  {'id': 153,
#   'startTime': 427.427,
#   'duration': 2.079999999999984,
#   'endTime': 429.507,
#   'text': '‐ Well, how long of a steam?',
#   'word_tag': [('‐', 'ADV'),
#    ('Well', 'ADV'),
#    (',', '.'),
#    ('how', 'ADV'),
#    ('long', 'ADV'),
#    ('of', 'ADP'),
#    ('a', 'DET'),
#    ('steam', 'NOUN'),
#    ('?', '.')]},
#  {'id': 154,
#   'startTime': 430.555,
#   'duration': 0.9370000000000118,
#   'endTime': 431.492,
#   'text': 'Phil?',
#   'word_tag': [('Phil', 'NOUN'), ('?', '.')]},
#  {'id': 155,
#   'startTime': 431.516,
#   'duration': 1.766999999999996,
#   'endTime': 433.283,
#   'text': 'Phil? Phil?',
#   'word_tag': [('Phil', 'NOUN'), ('?', '.'), ('Phil', 'NOUN'), ('?', '.')]},
#  {'id': 156,
#   'startTime': 433.307,
#   'duration': 1.478999999999985,
#   'endTime': 434.786,
#   'text': "Phil, where'd you go? Phil!",
#   'word_tag': [('Phil', 'NOUN'),
#    (',', '.'),
#    ('where', 'ADV'),
#    ("'d", 'VERB'),
#    ('you', 'PRON'),
#    ('go', 'VERB'),
#    ('?', '.'),
#    ('Phil', 'NOUN'),
#    ('!', '.')]},
#  {'id': 157,
#   'startTime': 434.81,
#   'duration': 1.0790000000000077,
#   'endTime': 435.889,
#   'text': '‐ Yes?',
#   'word_tag': [('‐', 'VERB'), ('Yes', 'X'), ('?', '.')]},
#  {'id': 158,
#   'startTime': 439.856,
#   'duration': 3.5,
#   'endTime': 443.356,
#   'text': "See? You're completely relaxed, thanks to the steam.",
#   'word_tag': [('See', 'VERB'),
#    ('?', '.'),
#    ('You', 'PRON'),
#    ("'re", 'VERB'),
#    ('completely', 'ADV'),
#    ('relaxed', 'ADJ'),
#    (',', '.'),
#    ('thanks', 'NOUN'),
#    ('to', 'PRT'),
#    ('the', 'DET'),
#    ('steam', 'NOUN'),
#    ('.', '.')]},
#  {'id': 159,
#   'startTime': 445.821,
#   'duration': 1.5179999999999723,
#   'endTime': 447.339,
#   'text': '‐ So sweet of you to offer.',
#   'word_tag': [('‐', 'NOUN'),
#    ('So', 'NOUN'),
#    ('sweet', 'NOUN'),
#    ('of', 'ADP'),
#    ('you', 'PRON'),
#    ('to', 'PRT'),
#    ('offer', 'VERB'),
#    ('.', '.')]},
#  {'id': 160,
#   'startTime': 447.363,
#   'duration': 2.021000000000015,
#   'endTime': 449.384,
#   'text': "But I'm making lunch. Okay?",
#   'word_tag': [('But', 'CONJ'),
#    ('I', 'PRON'),
#    ("'m", 'VERB'),
#    ('making', 'VERB'),
#    ('lunch', 'NOUN'),
#    ('.', '.'),
#    ('Okay', 'NOUN'),
#    ('?', '.')]},
#  {'id': 161,
#   'startTime': 449.408,
#   'duration': 2.562000000000012,
#   'endTime': 451.97,
#   'text': "‐ No. We're making lunch. Together.",
#   'word_tag': [('‐', 'ADJ'),
#    ('No', 'NOUN'),
#    ('.', '.'),
#    ('We', 'PRON'),
#    ("'re", 'VERB'),
#    ('making', 'VERB'),
#    ('lunch', 'NOUN'),
#    ('.', '.'),
#    ('Together', 'ADV'),
#    ('.', '.')]},
#  {'id': 162,
#   'startTime': 451.994,
#   'duration': 3.144999999999982,
#   'endTime': 455.139,
#   'text': '‐ Ohh. You wanna help make lunch?',
#   'word_tag': [('‐', 'ADJ'),
#    ('Ohh', 'NOUN'),
#    ('.', '.'),
#    ('You', 'PRON'),
#    ('wan', 'VERB'),
#    ('na', 'PRT'),
#    ('help', 'VERB'),
#    ('make', 'VERB'),
#    ('lunch', 'NOUN'),
#    ('?', '.')]},
#  {'id': 163,
#   'startTime': 455.163,
# ...
#    ('bounceberry', 'NOUN'),
#    ('harvest', 'NOUN'),
#    (',', '.'),
#    ('yes', 'X'),
#    ('?', '.')]},
#  {'id': 464,
#   'startTime': 1216.884,
#   'duration': 1.4839999999999236,
#   'endTime': 1218.368,
#   'text': '‐ By stopping the punch monkeys?',
#   'word_tag': [('‐', 'NOUN'),
#    ('By', 'ADP'),
#    ('stopping', 'VERB'),
#    ('the', 'DET'),
#    ('punch', 'NOUN'),
#    ('monkeys', 'NOUN'),
#    ('?', '.')]},
#  {'id': 465,
#   'startTime': 1218.393,
#   'duration': 1.0509999999999309,
#   'endTime': 1219.444,
#   'text': '‐ And fixing your mistake?',
#   'word_tag': [('‐', 'NOUN'),
#    ('And', 'CONJ'),
#    ('fixing', 'VERB'),
#    ('your', 'PRON'),
#    ('mistake', 'NOUN'),
#    ('?', '.')]},
#  {'id': 466,
#   'startTime': 1219.469,
#   'duration': 1.5199999999999818,
#   'endTime': 1220.989,
#   'text': "‐ Oh, I wouldn't put it like that.",
#   'word_tag': [('‐', 'NOUN'),
#    ('Oh', 'NOUN'),
#    (',', '.'),
#    ('I', 'PRON'),
#    ('would', 'VERB'),
#    ("n't", 'ADV'),
#    ('put', 'VERB'),
#    ('it', 'PRON'),
#    ('like', 'ADP'),
#    ('that', 'DET'),
#    ('.', '.')]},
#  {'id': 467,
#   'startTime': 1221.012,
#   'duration': 1.4360000000001492,
#   'endTime': 1222.448,
#   'text': "‐ I would. That's exactly it.",
#   'word_tag': [('‐', 'NOUN'),
#    ('I', 'PRON'),
#    ('would', 'VERB'),
#    ('.', '.'),
#    ('That', 'DET'),
#    ("'s", 'VERB'),
#    ('exactly', 'ADV'),
#    ('it', 'PRON'),
#    ('.', '.')]},
#  {'id': 468,
#   'startTime': 1222.471,
#   'duration': 0.8969999999999345,
#   'endTime': 1223.368,
#   'text': "‐ We're on it.",
#   'word_tag': [('‐', 'NOUN'),
#    ('We', 'PRON'),
#    ("'re", 'VERB'),
#    ('on', 'ADP'),
#    ('it', 'PRON'),
#    ('.', '.')]},
#  {'id': 469,
#   'startTime': 1223.393,
#   'duration': 2.314000000000078,
#   'endTime': 1225.707,
#   'text': "‐ And I'm all over it because this is how I roll now!",
#   'word_tag': [('‐', 'NOUN'),
#    ('And', 'CONJ'),
#    ('I', 'PRON'),
#    ("'m", 'VERB'),
#    ('all', 'DET'),
#    ('over', 'ADP'),
#    ('it', 'PRON'),
#    ('because', 'ADP'),
#    ('this', 'DET'),
#    ('is', 'VERB'),
#    ('how', 'ADV'),
#    ('I', 'PRON'),
#    ('roll', 'VERB'),
#    ('now', 'ADV'),
#    ('!', '.')]},
#  {'id': 470,
#   'startTime': 1225.73,
#   'duration': 2.8489999999999327,
#   'endTime': 1228.579,
#   'text': 'All Dawn, no rules, so deal with it!',
#   'word_tag': [('All', 'DET'),
#    ('Dawn', 'NOUN'),
#    (',', '.'),
#    ('no', 'DET'),
#    ('rules', 'NOUN'),
#    (',', '.'),
#    ('so', 'ADV'),
#    ('deal', 'ADJ'),
#    ('with', 'ADP'),
#    ('it', 'PRON'),
#    ('!', '.')]},
#  {'id': 471,
#   'startTime': 1228.604,
#   'duration': 0.6859999999999218,
#   'endTime': 1229.29,
#   'text': '‐ Same team, Dawn.',
#   'word_tag': [('‐', 'ADJ'),
#    ('Same', 'NOUN'),
#    ('team', 'NOUN'),
#    (',', '.'),
#    ('Dawn', 'NOUN'),
#    ('.', '.')]},
#  {'id': 472,
#   'startTime': 1229.315,
#   'duration': 2.6849999999999454,
#   'endTime': 1232,
#   'text': '‐ Yeah. The Kill Team!',
#   'word_tag': [('‐', 'ADJ'),
#    ('Yeah', 'NOUN'),
#    ('.', '.'),
#    ('The', 'DET'),
#    ('Kill', 'NOUN'),
#    ('Team', 'NOUN'),
#    ('!', '.')]},
#  {'id': 473,
#   'startTime': 1232.023,
#   'duration': 1.1860000000001492,
#   'endTime': 1233.209,
#   'text': '‐ Uh, no.',
#   'word_tag': [('‐', 'NOUN'),
#    ('Uh', 'NOUN'),
#    (',', '.'),
#    ('no', 'DET'),
#    ('.', '.')]},
#  {'id': 474,
#   'startTime': 1233.232,
#   'duration': 1.5190000000000055,
#   'endTime': 1234.751,
#   'text': 'No killing necessary.',
#   'word_tag': [('No', 'DET'),
#    ('killing', 'VERB'),
#    ('necessary', 'ADJ'),
#    ('.', '.')]},
#  {'id': 475,
#   'startTime': 1234.776,
#   'duration': 0.8940000000000055,
#   'endTime': 1235.67,
#   'text': "Here's the plan‐‐",
#   'word_tag': [('Here', 'ADV'),
#    ("'s", 'VERB'),
#    ('the', 'DET'),
#    ('plan‐‐', 'NOUN')]},
#  {'id': 476,
#   'startTime': 1235.693,
#   'duration': 3.1059999999999945,
#   'endTime': 1238.799,
#   'text': '‐ No offense, but your plan is why we need a new plan.',
#   'word_tag': [('‐', 'ADJ'),
#    ('No', 'NOUN'),
#    ('offense', 'NOUN'),
#    (',', '.'),
#    ('but', 'CONJ'),
#    ('your', 'PRON'),
#    ('plan', 'NOUN'),
#    ('is', 'VERB'),
#    ('why', 'ADV'),
#    ('we', 'PRON'),
#    ('need', 'VERB'),
#    ('a', 'DET'),
#    ('new', 'ADJ'),
#    ('plan', 'NOUN'),
#    ('.', '.')]},
#  {'id': 477,
#   'startTime': 1238.824,
#   'duration': 1.683999999999969,
#   'endTime': 1240.508,
#   'text': "‐ Right. So here's the plan.",
#   'word_tag': [('‐', 'ADV'),
#    ('Right', 'NOUN'),
#    ('.', '.'),
#    ('So', 'ADV'),
#    ('here', 'ADV'),
#    ("'s", 'VERB'),
#    ('the', 'DET'),
#    ('plan', 'NOUN'),
#    ('.', '.')]},
#  {'id': 478,
#   'startTime': 1240.531,
#   'duration': 2.019999999999982,
#   'endTime': 1242.551,
#   'text': 'Hey, punch monkeys!',
#   'word_tag': [('Hey', 'NOUN'),
#    (',', '.'),
#    ('punch', 'ADJ'),
#    ('monkeys', 'NOUN'),
#    ('!', '.')]},
#  {'id': 479,
#   'startTime': 1242.576,
#   'duration': 1.6440000000000055,
#   'endTime': 1244.22,
#   'text': 'You forgot the bounceberries.',
#   'word_tag': [('You', 'PRON'),
#    ('forgot', 'VERB'),
#    ('the', 'DET'),
#    ('bounceberries', 'NOUN'),
#    ('.', '.')]},
#  {'id': 480,
#   'startTime': 1244.243,
#   'duration': 1.3940000000000055,
#   'endTime': 1245.637,
#   'text': '‐ So we brought you a bunch.',
#   'word_tag': [('‐', 'NOUN'),
#    ('So', 'ADP'),
#    ('we', 'PRON'),
#    ('brought', 'VERB'),
#    ('you', 'PRON'),
#    ('a', 'DET'),
#    ('bunch', 'NOUN'),
#    ('.', '.')]},
#  {'id': 481,
#   'startTime': 1245.662,
#   'duration': 1,
#   'endTime': 1246.662,
#   'text': '‐ To go.',
#   'word_tag': [('‐', 'NOUN'), ('To', 'PRT'), ('go', 'VERB'), ('.', '.')]},
#  {'id': 482,
#   'startTime': 1248.164,
#   'duration': 3.270999999999958,
#   'endTime': 1251.435,
#   'text': 'Look at us, working together, bouncing together.',
#   'word_tag': [('Look', 'NOUN'),
#    ('at', 'ADP'),
#    ('us', 'PRON'),
#    (',', '.'),
#    ('working', 'VERB'),
#    ('together', 'ADV'),
#    (',', '.'),
#    ('bouncing', 'VERB'),
#    ('together', 'ADV'),
#    ('.', '.')]},
#  {'id': 483,
#   'startTime': 1251.46,
#   'duration': 1.1859999999999218,
#   'endTime': 1252.646,
#   'text': 'This is a real moment.',
#   'word_tag': [('This', 'DET'),
#    ('is', 'VERB'),
#    ('a', 'DET'),
#    ('real', 'ADJ'),
#    ('moment', 'NOUN'),
#    ('.', '.')]},
#  {'id': 484,
#   'startTime': 1252.671,
#   'duration': 1.2670000000000528,
#   'endTime': 1253.938,
#   'text': 'Whoo‐‐',
#   'word_tag': [('Whoo‐‐', 'NOUN')]},
#  {'id': 485,
#   'startTime': 1253.961,
#   'duration': 1.4359999999999218,
#   'endTime': 1255.397,
#   'text': 'Woo‐hoo!',
#   'word_tag': [('Woo‐hoo', 'NOUN'), ('!', '.')]},
#  {'id': 486,
#   'startTime': 1255.422,
#   'duration': 1.1849999999999454,
#   'endTime': 1256.607,
#   'text': 'Whoa!',
#   'word_tag': [('Whoa', 'NOUN'), ('!', '.')]},
#  {'id': 487,
#   'startTime': 1256.632,
#   'duration': 2.3099999999999454,
#   'endTime': 1258.942,
#   'text': 'Boy, I am really up here.',
#   'word_tag': [('Boy', 'NOUN'),
#    (',', '.'),
#    ('I', 'PRON'),
#    ('am', 'VERB'),
#    ('really', 'ADV'),
#    ('up', 'ADV'),
#    ('here', 'ADV'),
#    ('.', '.')]},
#  {'id': 488,
#   'startTime': 1258.967,
#   'duration': 1.1440000000000055,
#   'endTime': 1260.111,
#   'text': 'Oh, pretty clouds!',
#   'word_tag': [('Oh', 'X'),
#    (',', '.'),
#    ('pretty', 'ADJ'),
#    ('clouds', 'NOUN'),
#    ('!', '.')]},
#  {'id': 489,
#   'startTime': 1260.134,
#   'duration': 1.0609999999999218,
#   'endTime': 1261.195,
#   'text': 'That one looks like a pillow.',
#   'word_tag': [('That', 'DET'),
#    ('one', 'NUM'),
#    ('looks', 'VERB'),
#    ('like', 'ADP'),
#    ('a', 'DET'),
#    ('pillow', 'NOUN'),
#    ('.', '.')]},
#  {'id': 490,
#   'startTime': 1261.22,
#   'duration': 2.1849999999999454,
#   'endTime': 1263.405,
#   'text': "And there's an egg, a coconut, Thunk,",
#   'word_tag': [('And', 'CONJ'),
#    ('there', 'DET'),
#    ("'s", 'VERB'),
#    ('an', 'DET'),
#    ('egg', 'NOUN'),
#    (',', '.'),
#    ('a', 'DET'),
#    ('coconut', 'NOUN'),
#    (',', '.'),
#    ('Thunk', 'NOUN'),
#    (',', '.')]},
#  {'id': 491,
#   'startTime': 1263.43,
#   'duration': 1.4769999999998618,
#   'endTime': 1264.907,
#   'text': 'a‐a‐and going down.',
#   'word_tag': [('a‐a‐and', 'NOUN'),
#    ('going', 'VERB'),
#    ('down', 'PRT'),
#    ('.', '.')]},
#  {'id': 492,
#   'startTime': 1264.932,
#   'duration': 1.2270000000000891,
#   'endTime': 1266.159,
#   'text': 'Whoo!',
#   'word_tag': [('Whoo', 'NOUN'), ('!', '.')]},
#  {'id': 493,
#   'startTime': 1266.182,
#   'duration': 1.2690000000000055,
#   'endTime': 1267.451,
#   'text': 'Going back up.',
#   'word_tag': [('Going', 'VERB'), ('back', 'ADV'), ('up', 'ADV'), ('.', '.')]},
#  {'id': 494,
#   'startTime': 1267.476,
#   'duration': 2.019999999999982,
#   'endTime': 1269.496,
#   'text': 'Oh, yeah!',
#   'word_tag': [('Oh', 'X'), (',', '.'), ('yeah', 'X'), ('!', '.')]},
#  {'id': 495,
#   'startTime': 1269.519,
#   'duration': 1.2899999999999636,
#   'endTime': 1270.809,
#   'text': '‐ Guy.',
#   'word_tag': [('‐', 'ADJ'), ('Guy', 'NOUN'), ('.', '.')]},
#  {'id': 496,
#   'startTime': 1271.313,
#   'duration': 1.7269999999998618,
#   'endTime': 1273.04,
#   'text': '‐ Hey, no bounce‐frogging.',
#   'word_tag': [('‐', 'NOUN'),
#    ('Hey', 'NOUN'),
#    (',', '.'),
#    ('no', 'DET'),
#    ('bounce‐frogging', 'NOUN'),
#    ('.', '.')]},
#  {'id': 497,
#   'startTime': 1273.065,
#   'duration': 1.7899999999999636,
#   'endTime': 1274.855,
#   'text': 'This is serious monkey business.',
#   'word_tag': [('This', 'DET'),
#    ('is', 'VERB'),
#    ('serious', 'ADJ'),
#    ('monkey', 'NOUN'),
#    ('business', 'NOUN'),
#    ('.', '.')]},
#  {'id': 498,
#   'startTime': 1278.903,
#   'duration': 3.770999999999958,
#   'endTime': 1282.674,
#   'text': "‐ It's time to chew and shoo these monkeys outta here.",
#   'word_tag': [('‐', 'ADP'),
#    ('It', 'PRON'),
#    ("'s", 'VERB'),
#    ('time', 'NOUN'),
#    ('to', 'PRT'),
#    ('chew', 'VERB'),
#    ('and', 'CONJ'),
#    ('shoo', 'VERB'),
#    ('these', 'DET'),
#    ('monkeys', 'NOUN'),
#    ('outta', 'VERB'),
#    ('here', 'ADV'),
#    ('.', '.')]},
#  {'id': 499,
#   'startTime': 1282.699,
#   'duration': 1.7100000000000364,
#   'endTime': 1284.409,
#   'text': 'Everyone, chew!',
#   'word_tag': [('Everyone', 'NOUN'),
#    (',', '.'),
#    ('chew', 'NOUN'),
#    ('!', '.')]},
#  {'id': 500,
#   'startTime': 1286.619,
#   'duration': 1.5410000000001673,
#   'endTime': 1288.16,
#   'text': 'And shoo!',
#   'word_tag': [('And', 'CONJ'), ('shoo', 'NOUN'), ('!', '.')]},
#  {'id': 501,
#   'startTime': 1294.586,
#   'duration': 1.7889999999999873,
#   'endTime': 1296.375,
#   'text': 'Abandon berries!',
#   'word_tag': [('Abandon', 'NOUN'), ('berries', 'NOUN'), ('!', '.')]},
#  {'id': 502,
#   'startTime': 1301.801,
#   'duration': 1,
#   'endTime': 1302.801,
#   'text': 'Gotcha!',
#   'word_tag': [('Gotcha', 'NOUN'), ('!', '.')]},
#  {'id': 503,
#   'startTime': 1304.93,
#   'duration': 1.9600000000000364,
#   'endTime': 1306.89,
#   'text': "Phil and Hope, you're up!",
#   'word_tag': [('Phil', 'NOUN'),
#    ('and', 'CONJ'),
#    ('Hope', 'NOUN'),
#    (',', '.'),
#    ('you', 'PRON'),
#    ("'re", 'VERB'),
#    ('up', 'PRT'),
#    ('!', '.')]},
#  {'id': 504,
#   'startTime': 1314.146,
#   'duration': 3.230000000000018,
#   'endTime': 1317.376,
#   'text': "‐ And that's how you bounce punch monkeys out the door.",
#   'word_tag': [('‐', 'NOUN'),
#    ('And', 'CONJ'),
#    ('that', 'DET'),
#    ("'s", 'VERB'),
#    ('how', 'ADV'),
#    ('you', 'PRON'),
#    ('bounce', 'VERB'),
#    ('punch', 'ADJ'),
#    ('monkeys', 'NOUN'),
#    ('out', 'PRT'),
#    ('the', 'DET'),
#    ('door', 'NOUN'),
#    ('.', '.')]},
#  {'id': 505,
#   'startTime': 1317.401,
#   'duration': 3.811999999999898,
#   'endTime': 1321.213,
#   'text': '‐ Along with all our bounceberries!',
#   'word_tag': [('‐', 'NOUN'),
#    ('Along', 'ADP'),
#    ('with', 'ADP'),
#    ('all', 'DET'),
#    ('our', 'PRON'),
#    ('bounceberries', 'NOUN'),
#    ('!', '.')]},
#  {'id': 506,
#   'startTime': 1321.238,
#   'duration': 2.7100000000000364,
#   'endTime': 1323.948,
#   'text': 'Except for that one. Which you are eating.',
#   'word_tag': [('Except', 'ADP'),
#    ('for', 'ADP'),
#    ('that', 'DET'),
#    ('one', 'NUM'),
#    ('.', '.'),
#    ('Which', 'ADP'),
#    ('you', 'PRON'),
#    ('are', 'VERB'),
#    ('eating', 'VERB'),
#    ('.', '.')]},
#  {'id': 507,
#   'startTime': 1326.41,
#   'duration': 0.7680000000000291,
#   'endTime': 1327.178,
#   'text': 'Ugh!',
#   'word_tag': [('Ugh', 'NOUN'), ('!', '.')]},
#  {'id': 508,
#   'startTime': 1327.201,
#   'duration': 2.686999999999898,
#   'endTime': 1329.888,
#   'text': '‐ The point is, we did it together.',
#   'word_tag': [('‐', 'VERB'),
#    ('The', 'DET'),
#    ('point', 'NOUN'),
#    ('is', 'VERB'),
#    (',', '.'),
#    ('we', 'PRON'),
#    ('did', 'VERB'),
#    ('it', 'PRON'),
#    ('together', 'ADV'),
#    ('.', '.')]},
#  {'id': 509,
#   'startTime': 1329.913,
#   'duration': 2.98700000000008,
#   'endTime': 1332.9,
#   'text': 'We built a bridge between ourselves and we crossed it.',
#   'word_tag': [('We', 'PRON'),
#    ('built', 'VERB'),
#    ('a', 'DET'),
#    ('bridge', 'NOUN'),
#    ('between', 'ADP'),
#    ('ourselves', 'NOUN'),
#    ('and', 'CONJ'),
#    ('we', 'PRON'),
#    ('crossed', 'VERB'),
#    ('it', 'PRON'),
#    ('.', '.')]},
#  {'id': 510,
#   'startTime': 1332.923,
#   'duration': 3.43100000000004,
#   'endTime': 1336.354,
#   'text': '‐ No. The point is, we found our purpose here.',
#   'word_tag': [('‐', 'ADJ'),
#    ('No', 'NOUN'),
#    ('.', '.'),
#    ('The', 'DET'),
#    ('point', 'NOUN'),
#    ('is', 'VERB'),
#    (',', '.'),
#    ('we', 'PRON'),
#    ('found', 'VERB'),
#    ('our', 'PRON'),
#    ('purpose', 'NOUN'),
#    ('here', 'ADV'),
#    ('.', '.')]},
#  {'id': 511,
#   'startTime': 1336.377,
#   'duration': 1.8949999999999818,
#   'endTime': 1338.272,
#   'text': "Fixing Phil's mistakes.",
#   'word_tag': [('Fixing', 'VERB'),
#    ('Phil', 'NOUN'),
#    ("'s", 'PRT'),
#    ('mistakes', 'NOUN'),
#    ('.', '.')]},
#  {'id': 512,
#   'startTime': 1338.297,
#   'duration': 1.2690000000000055,
#   'endTime': 1339.566,
#   'text': '‐ Starting with the system.',
#   'word_tag': [('‐', 'NOUN'),
#    ('Starting', 'VERB'),
#    ('with', 'ADP'),
#    ('the', 'DET'),
#    ('system', 'NOUN'),
#    ('.', '.')]},
#  {'id': 513,
#   'startTime': 1339.589,
#   'duration': 2.394999999999982,
#   'endTime': 1341.984,
#   'text': "Yeah, let's crush the system!",
#   'word_tag': [('Yeah', 'X'),
#    (',', '.'),
#    ('let', 'VERB'),
#    ("'s", 'PRT'),
#    ('crush', 'VERB'),
#    ('the', 'DET'),
#    ('system', 'NOUN'),
#    ('!', '.')]},
#  {'id': 514,
#   'startTime': 1342.009,
#   'duration': 2.3559999999999945,
#   'endTime': 1344.365,
#   'text': '‐ Ooh. And afterwards maybe we could play Catch.',
#   'word_tag': [('‐', 'ADJ'),
#    ('Ooh', 'NOUN'),
#    ('.', '.'),
#    ('And', 'CONJ'),
#    ('afterwards', 'NOUN'),
#    ('maybe', 'ADV'),
#    ('we', 'PRON'),
#    ('could', 'VERB'),
#    ('play', 'VERB'),
#    ('Catch', 'NOUN'),
#    ('.', '.')]},
#  {'id': 515,
#   'startTime': 1344.39,
#   'duration': 2.3079999999999927,
#   'endTime': 1346.698,
#   'text': "‐ No! They'll ruin the system.",
#   'word_tag': [('‐', 'ADJ'),
#    ('No', 'DET'),
#    ('!', '.'),
#    ('They', 'PRON'),
#    ("'ll", 'VERB'),
#    ('ruin', 'VERB'),
#    ('the', 'DET'),
#    ('system', 'NOUN'),
#    ('.', '.')]},
#  {'id': 516,
#   'startTime': 1346.721,
#   'duration': 1.1440000000000055,
#   'endTime': 1347.865,
#   'text': '‐ Who cares?',
#   'word_tag': [('‐', 'NOUN'), ('Who', 'PRON'), ('cares', 'VERB'), ('?', '.')]},
#  {'id': 517,
#   'startTime': 1347.89,
#   'duration': 2.977999999999838,
#   'endTime': 1350.868,
#   'text': "If they're busy, I get my kitchen back. So I win.",
#   'word_tag': [('If', 'ADP'),
#    ('they', 'PRON'),
#    ("'re", 'VERB'),
#    ('busy', 'ADJ'),
#    (',', '.'),
#    ('I', 'PRON'),
#    ('get', 'VERB'),
#    ('my', 'PRON'),
#    ('kitchen', 'NOUN'),
#    ('back', 'ADV'),
#    ('.', '.'),
#    ('So', 'ADP'),
#    ('I', 'PRON'),
#    ('win', 'VERB'),
#    ('.', '.')]},
#  {'id': 518,
#   'startTime': 1350.893,
#   'duration': 1.9349999999999454,
#   'endTime': 1352.828,
#   'text': 'Which means you win.',
#   'word_tag': [('Which', 'ADJ'),
#    ('means', 'VERB'),
#    ('you', 'PRON'),
#    ('win', 'VERB'),
#    ('.', '.')]},
#  {'id': 519,
#   'startTime': 1352.853,
#   'duration': 2.168999999999869,
#   'endTime': 1355.022,
#   'text': "‐ You're right. High five.",
#   'word_tag': [('‐', 'NOUN'),
#    ('You', 'PRON'),
#    ("'re", 'VERB'),
#    ('right', 'ADJ'),
#    ('.', '.'),
#    ('High', 'ADJ'),
#    ('five', 'NUM'),
#    ('.', '.')]},
#  {'id': 520,
#   'startTime': 1356.815,
#   'duration': 2.0399999999999636,
#   'endTime': 1358.855,
#   'text': "‐ And we're stuck.",
#   'word_tag': [('‐', 'NOUN'),
#    ('And', 'CONJ'),
#    ('we', 'PRON'),
#    ("'re", 'VERB'),
#    ('stuck', 'VERB'),
#    ('.', '.')]}]

# %%
with open('subWithWords.json', 'w') as out:
    json.dump(data, out)
