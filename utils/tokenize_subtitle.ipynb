# %%
import json
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag, map_tag
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('universal_tagset')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\MohammadJavad\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\MohammadJavad\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\MohammadJavad\AppData\Roaming\nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# True

# %%
with open('subtitle.json', encoding='utf-8') as f:
    data = json.load(f)

# %%
data[0]['text']
# Out:
# "I'm Eep. Of the Croods clan."

# %%
word_tokenize(data[0]['text'])
# Out:
# ['I', "'m", 'Eep', '.', 'Of', 'the', 'Croods', 'clan', '.']

# %%
def pos_tagger(item):
    text = nltk.word_tokenize(item['text'])
    posTagged = pos_tag(text)
    simplifiedTags = [(word, map_tag('en-ptb', 'universal', tag)) for word, tag in posTagged]
    return simplifiedTags

# %%
for item in data:
    tags = pos_tagger(item)
    item['word_tag'] = tags

# %%
data
# Out:
# [{'id': 1,
#   'duration': 2954,
#   'text': "I'm Eep. Of the Croods clan.",
#   'word_tag': [('I', 'PRON'),
#    ("'m", 'VERB'),
#    ('Eep', 'ADJ'),
#    ('.', '.'),
#    ('Of', 'ADP'),
#    ('the', 'DET'),
#    ('Croods', 'NOUN'),
#    ('clan', 'NOUN'),
#    ('.', '.')]},
#  {'id': 2,
#   'duration': 1000,
#   'text': 'Gotcha!',
#   'word_tag': [('Gotcha', 'NOUN'), ('!', '.')]},
#  {'id': 3,
#   'duration': 1975,
#   'text': "And I'm on the hunt.",
#   'word_tag': [('And', 'CONJ'),
#    ('I', 'PRON'),
#    ("'m", 'VERB'),
#    ('on', 'ADP'),
#    ('the', 'DET'),
#    ('hunt', 'NOUN'),
#    ('.', '.')]},
#  {'id': 4,
#   'duration': 1035,
#   'text': 'But not for food.',
#   'word_tag': [('But', 'CONJ'),
#    ('not', 'ADV'),
#    ('for', 'ADP'),
#    ('food', 'NOUN'),
#    ('.', '.')]},
#  {'id': 5,
#   'duration': 2013,
#   'text': "That's old Eep. I'm new Eep.",
#   'word_tag': [('That', 'DET'),
#    ("'s", 'VERB'),
#    ('old', 'ADJ'),
#    ('Eep', 'NOUN'),
#    ('.', '.'),
#    ('I', 'PRON'),
#    ("'m", 'VERB'),
#    ('new', 'ADJ'),
#    ('Eep', 'NOUN'),
#    ('.', '.')]},
#  {'id': 6,
#   'duration': 1029,
#   'text': 'Whoo!',
#   'word_tag': [('Whoo', 'NOUN'), ('!', '.')]},
#  {'id': 7,
#   'duration': 1000,
#   'text': 'Ha!',
#   'word_tag': [('Ha', 'NOUN'), ('!', '.')]},
#  {'id': 8,
#   'duration': 2063,
#   'text': 'And new Eep just needs a pen.',
#   'word_tag': [('And', 'CONJ'),
#    ('new', 'ADJ'),
#    ('Eep', 'NOUN'),
#    ('just', 'ADV'),
#    ('needs', 'VERB'),
#    ('a', 'DET'),
#    ('pen', 'NOUN'),
#    ('.', '.')]},
#  {'id': 9,
#   'duration': 1022,
#   'text': '‐ Dear Bark Journal,',
#   'word_tag': [('‐', 'ADJ'),
#    ('Dear', 'NOUN'),
#    ('Bark', 'NOUN'),
#    ('Journal', 'NOUN'),
#    (',', '.')]},
#  {'id': 10,
#   'duration': 2006,
#   'text': 'so what put the new in new me?',
#   'word_tag': [('so', 'ADV'),
#    ('what', 'PRON'),
#    ('put', 'VERB'),
#    ('the', 'DET'),
#    ('new', 'ADJ'),
#    ('in', 'ADP'),
#    ('new', 'ADJ'),
#    ('me', 'PRON'),
#    ('?', '.')]},
#  {'id': 11,
#   'duration': 2936,
#   'text': "I'm glad I asked myself that question.",
#   'word_tag': [('I', 'PRON'),
#    ("'m", 'VERB'),
#    ('glad', 'ADJ'),
#    ('I', 'PRON'),
#    ('asked', 'VERB'),
#    ('myself', 'PRON'),
#    ('that', 'ADP'),
#    ('question', 'NOUN'),
#    ('.', '.')]},
#  {'id': 12,
#   'duration': 1031,
#   'text': 'I was walking with my family,',
#   'word_tag': [('I', 'PRON'),
#    ('was', 'VERB'),
#    ('walking', 'VERB'),
#    ('with', 'ADP'),
#    ('my', 'PRON'),
#    ('family', 'NOUN'),
#    (',', '.')]},
#  {'id': 13,
#   'duration': 1964,
#   'text': 'my dad Grug, my mom Ugga,',
#   'word_tag': [('my', 'PRON'),
#    ('dad', 'ADJ'),
#    ('Grug', 'NOUN'),
#    (',', '.'),
#    ('my', 'PRON'),
#    ('mom', 'NOUN'),
#    ('Ugga', 'NOUN'),
#    (',', '.')]},
#  {'id': 14,
#   'duration': 1997,
#   'text': 'my little brother Thunk, my little sister Sandy,',
#   'word_tag': [('my', 'PRON'),
#    ('little', 'ADJ'),
#    ('brother', 'NOUN'),
#    ('Thunk', 'NOUN'),
#    (',', '.'),
#    ('my', 'PRON'),
#    ('little', 'ADJ'),
#    ('sister', 'ADJ'),
#    ('Sandy', 'NOUN'),
#    (',', '.')]},
#  {'id': 15,
#   'duration': 1977,
#   'text': 'my gran Gran, and Guy,',
#   'word_tag': [('my', 'PRON'),
#    ('gran', 'NOUN'),
#    ('Gran', 'NOUN'),
#    (',', '.'),
#    ('and', 'CONJ'),
#    ('Guy', 'NOUN'),
#    (',', '.')]},
#  {'id': 16,
#   'duration': 3031,
#   'text': 'as in my guy, the guy of my dreams but real.',
#   'word_tag': [('as', 'ADP'),
#    ('in', 'ADP'),
#    ('my', 'PRON'),
#    ('guy', 'NOUN'),
#    (',', '.'),
#    ('the', 'DET'),
#    ('guy', 'NOUN'),
#    ('of', 'ADP'),
#    ('my', 'PRON'),
#    ('dreams', 'NOUN'),
#    ('but', 'CONJ'),
#    ('real', 'ADJ'),
#    ('.', '.')]},
#  {'id': 17,
#   'duration': 1001,
#   'text': 'And we hit a wall.',
#   'word_tag': [('And', 'CONJ'),
#    ('we', 'PRON'),
#    ('hit', 'VERB'),
#    ('a', 'DET'),
#    ('wall', 'NOUN'),
#    ('.', '.')]},
#  {'id': 18,
#   'duration': 1044,
#   'text': 'So, of course, Dad smashed through it.',
#   'word_tag': [('So', 'ADV'),
#    (',', '.'),
#    ('of', 'ADP'),
#    ('course', 'NOUN'),
#    (',', '.'),
#    ('Dad', 'NOUN'),
#    ('smashed', 'VERB'),
#    ('through', 'ADP'),
#    ('it', 'PRON'),
#    ('.', '.')]},
#  {'id': 19,
#   'duration': 1944,
#   'text': 'And there was a farm and a tree house.',
#   'word_tag': [('And', 'CONJ'),
#    ('there', 'DET'),
#    ('was', 'VERB'),
#    ('a', 'DET'),
#    ('farm', 'NOUN'),
#    ('and', 'CONJ'),
#    ('a', 'DET'),
#    ('tree', 'ADJ'),
#    ('house', 'NOUN'),
#    ('.', '.')]},
#  {'id': 20,
#   'duration': 2977,
#   'text': 'And a family, the Bettermans, Phil, Hope and their daughter Dawn.',
#   'word_tag': [('And', 'CONJ'),
#    ('a', 'DET'),
#    ('family', 'NOUN'),
#    (',', '.'),
#    ('the', 'DET'),
#    ('Bettermans', 'NOUN'),
#    (',', '.'),
#    ('Phil', 'NOUN'),
#    (',', '.'),
#    ('Hope', 'NOUN'),
#    ('and', 'CONJ'),
#    ('their', 'PRON'),
#    ('daughter', 'NOUN'),
#    ('Dawn', 'NOUN'),
#    ('.', '.')]},
#  {'id': 21,
#   'duration': 2053,
#   'text': "They weren't happy about their wall, and we didn't get along.",
#   'word_tag': [('They', 'PRON'),
#    ('were', 'VERB'),
#    ("n't", 'ADV'),
#    ('happy', 'ADJ'),
#    ('about', 'ADP'),
#    ('their', 'PRON'),
#    ('wall', 'NOUN'),
#    (',', '.'),
#    ('and', 'CONJ'),
#    ('we', 'PRON'),
#    ('did', 'VERB'),
#    ("n't", 'ADV'),
#    ('get', 'VERB'),
#    ('along', 'ADV'),
#    ('.', '.')]},
#  {'id': 22,
#   'duration': 2010,
#   'text': 'But then we were attacked by these crazy punch monkeys',
#   'word_tag': [('But', 'CONJ'),
#    ('then', 'ADV'),
#    ('we', 'PRON'),
#    ('were', 'VERB'),
#    ('attacked', 'VERB'),
#    ('by', 'ADP'),
#    ('these', 'DET'),
#    ('crazy', 'ADJ'),
#    ('punch', 'NOUN'),
#    ('monkeys', 'NOUN')]},
#  {'id': 23,
#   'duration': 1031,
#   'text': 'so we had to team up to survive.',
#   'word_tag': [('so', 'ADP'),
#    ('we', 'PRON'),
#    ('had', 'VERB'),
#    ('to', 'PRT'),
#    ('team', 'VERB'),
#    ('up', 'ADV'),
#    ('to', 'PRT'),
#    ('survive', 'VERB'),
#    ('.', '.')]},
#  {'id': 24,
#   'duration': 2984,
#   'text': 'It went so well, the Bettermans invited us to move in,',
#   'word_tag': [('It', 'PRON'),
#    ('went', 'VERB'),
#    ('so', 'ADV'),
#    ('well', 'ADV'),
#    (',', '.'),
#    ('the', 'DET'),
#    ('Bettermans', 'NOUN'),
#    ('invited', 'VERB'),
#    ('us', 'PRON'),
#    ('to', 'PRT'),
#    ('move', 'VERB'),
#    ('in', 'ADP'),
#    (',', '.')]},
#  {'id': 25,
#   'duration': 1993,
#   'text': 'and, boom, first neighborhood ever!',
#   'word_tag': [('and', 'CONJ'),
#    (',', '.'),
#    ('boom', 'NOUN'),
#    (',', '.'),
#    ('first', 'ADV'),
#    ('neighborhood', 'ADJ'),
#    ('ever', 'ADV'),
#    ('!', '.')]},
#  {'id': 26,
#   'duration': 1978,
#   'text': 'And, boom, again, first best friend ever!',
#   'word_tag': [('And', 'CONJ'),
#    (',', '.'),
#    ('boom', 'NOUN'),
#    (',', '.'),
#    ('again', 'ADV'),
#    (',', '.'),
#    ('first', 'ADV'),
#    ('best', 'ADJ'),
#    ('friend', 'NOUN'),
#    ('ever', 'ADV'),
#    ('!', '.')]},
#  {'id': 27,
#   'duration': -52999,
#   'text': 'Dawn rocks!',
#   'word_tag': [('Dawn', 'NOUN'), ('rocks', 'NOUN'), ('!', '.')]},
#  {'id': 28,
#   'duration': 1018,
#   'text': "But the punch monkeys don't,",
#   'word_tag': [('But', 'CONJ'),
#    ('the', 'DET'),
#    ('punch', 'NOUN'),
#    ('monkeys', 'NOUN'),
#    ('do', 'VERB'),
#    ("n't", 'ADV'),
#    (',', '.')]},
#  {'id': 29,
#   'duration': 2944,
#   'text': 'so welcome back, wall, and hello, peace and quiet.',
#   'word_tag': [('so', 'ADV'),
#    ('welcome', 'ADJ'),
#    ('back', 'ADV'),
#    (',', '.'),
#    ('wall', 'NOUN'),
#    (',', '.'),
#    ('and', 'CONJ'),
#    ('hello', 'NOUN'),
#    (',', '.'),
#    ('peace', 'NOUN'),
#    ('and', 'CONJ'),
#    ('quiet', 'ADJ'),
#    ('.', '.')]},
#  {'id': 30,
#   'duration': 2022,
#   'text': "Yep, the Croods are livin' easy now.",
#   'word_tag': [('Yep', 'NOUN'),
#    (',', '.'),
#    ('the', 'DET'),
#    ('Croods', 'NOUN'),
#    ('are', 'VERB'),
#    ('livin', 'ADJ'),
#    ("'", 'PRT'),
#    ('easy', 'ADJ'),
#    ('now', 'ADV'),
#    ('.', '.')]},
#  {'id': 31,
#   'duration': 1984,
#   'text': "Except it's not so easy.",
#   'word_tag': [('Except', 'ADP'),
#    ('it', 'PRON'),
#    ("'s", 'VERB'),
#    ('not', 'ADV'),
#    ('so', 'ADV'),
#    ('easy', 'ADJ'),
#    ('.', '.')]},
#  {'id': 32,
#   'duration': 1077,
#   'text': '‐ Is it night yet?',
#   'word_tag': [('‐', 'NOUN'),
#    ('Is', 'VERB'),
#    ('it', 'PRON'),
#    ('night', 'NOUN'),
#    ('yet', 'ADV'),
#    ('?', '.')]},
#  {'id': 33,
#   'duration': 1994,
#   'text': '‐ No, honey, we just woke up.',
#   'word_tag': [('‐', 'NOUN'),
#    ('No', 'NOUN'),
#    (',', '.'),
#    ('honey', 'NOUN'),
#    (',', '.'),
#    ('we', 'PRON'),
#    ('just', 'ADV'),
#    ('woke', 'VERB'),
#    ('up', 'PRT'),
#    ('.', '.')]},
#  {'id': 34,
#   'duration': 1961,
#   'text': '‐ Aw, come on!',
#   'word_tag': [('‐', 'NOUN'),
#    ('Aw', 'NOUN'),
#    (',', '.'),
#    ('come', 'VERB'),
#    ('on', 'ADP'),
#    ('!', '.')]},
#  {'id': 35,
#   'duration': 2956,
#   'text': 'No hunting, no chasing.',
#   'word_tag': [('No', 'DET'),
#    ('hunting', 'NOUN'),
#    (',', '.'),
#    ('no', 'DET'),
#    ('chasing', 'NOUN'),
#    ('.', '.')]},
#  {'id': 36,
#   'duration': 1021,
#   'text': '‐ No fighting.',
#   'word_tag': [('‐', 'ADJ'), ('No', 'DET'), ('fighting', 'NOUN'), ('.', '.')]},
#  {'id': 37,
#   'duration': 1010,
#   'text': '‐ Sorry, Sandy.',
#   'word_tag': [('‐', 'NOUN'),
#    ('Sorry', 'NOUN'),
#    (',', '.'),
#    ('Sandy', 'NOUN'),
#    ('.', '.')]},
#  {'id': 38,
#   'duration': 1014,
#   'text': 'Nothing to fight here.',
#   'word_tag': [('Nothing', 'NOUN'),
#    ('to', 'PRT'),
#    ('fight', 'VERB'),
#    ('here', 'ADV'),
#    ('.', '.')]},
#  {'id': 39,
#   'duration': 2044,
#   'text': 'The farm has food, shelter, and safety.',
#   'word_tag': [('The', 'DET'),
#    ('farm', 'NOUN'),
#    ('has', 'VERB'),
#    ('food', 'NOUN'),
#    (',', '.'),
#    ('shelter', 'NOUN'),
#    (',', '.'),
#    ('and', 'CONJ'),
#    ('safety', 'NOUN'),
#    ('.', '.')]},
#  {'id': 40,
#   'duration': 1985,
#   'text': "It's comfortable, predictable‐‐",
#   'word_tag': [('It', 'PRON'),
#    ("'s", 'VERB'),
#    ('comfortable', 'ADJ'),
#    (',', '.'),
#    ('predictable‐‐', 'NOUN')]},
#  {'id': 41,
#   'duration': 2973,
#   'text': '‐ And so‐o‐o‐o boring!',
#   'word_tag': [('‐', 'NOUN'),
#    ('And', 'CONJ'),
#    ('so‐o‐o‐o', 'NOUN'),
#    ('boring', 'NOUN'),
#    ('!', '.')]},
#  {'id': 42,
#   'duration': 1989,
#   'text': '‐ Relaxing?',
#   'word_tag': [('‐', 'NOUN'), ('Relaxing', 'NOUN'), ('?', '.')]},
#  {'id': 43,
#   'duration': 1977,
#   'text': 'Good. Keep doing that.',
#   'word_tag': [('Good', 'ADJ'),
#    ('.', '.'),
#    ('Keep', 'VERB'),
#    ('doing', 'VERB'),
#    ('that', 'DET'),
#    ('.', '.')]},
#  {'id': 44,
#   'duration': 1061,
#   'text': '‐ Can we help with anything, Hope?',
#   'word_tag': [('‐', 'NOUN'),
#    ('Can', 'VERB'),
#    ('we', 'PRON'),
#    ('help', 'VERB'),
#    ('with', 'ADP'),
#    ('anything', 'NOUN'),
#    (',', '.'),
#    ('Hope', 'NOUN'),
#    ('?', '.')]},
#  {'id': 45,
#   'duration': 2935,
#   'text': "‐ Nope. Everything's taken care of.",
#   'word_tag': [('‐', 'ADJ'),
#    ('Nope', 'NOUN'),
#    ('.', '.'),
#    ('Everything', 'NOUN'),
#    ("'s", 'PRT'),
#    ('taken', 'VERB'),
#    ('care', 'NOUN'),
#    ('of', 'ADP'),
#    ('.', '.')]},
#  {'id': 46,
#   'duration': 1989,
#   'text': 'Ew!',
#   'word_tag': [('Ew', 'NOUN'), ('!', '.')]},
#  {'id': 47,
#   'duration': 1085,
#   'text': "So I'll make lunch",
#   'word_tag': [('So', 'ADV'),
#    ('I', 'PRON'),
#    ("'ll", 'VERB'),
#    ('make', 'VERB'),
#    ('lunch', 'NOUN')]},
#  {'id': 48,
#   'duration': 1960,
#   'text': 'and you stay out of the way and do nothing.',
#   'word_tag': [('and', 'CONJ'),
#    ('you', 'PRON'),
#    ('stay', 'VERB'),
#    ('out', 'ADP'),
#    ('of', 'ADP'),
#    ('the', 'DET'),
#    ('way', 'NOUN'),
#    ('and', 'CONJ'),
#    ('do', 'VERB'),
#    ('nothing', 'NOUN'),
#    ('.', '.')]},
#  {'id': 49,
#   'duration': 982,
#   'text': 'Bye!',
#   'word_tag': [('Bye', 'NOUN'), ('!', '.')]},
#  {'id': 50,
#   'duration': 1035,
#   'text': '‐ Do nothing?',
#   'word_tag': [('‐', 'NOUN'),
#    ('Do', 'VERB'),
#    ('nothing', 'NOUN'),
#    ('?', '.')]},
#  {'id': 51,
#   'duration': 1919,
#   'text': "We're the Croods!",
#   'word_tag': [('We', 'PRON'),
#    ("'re", 'VERB'),
#    ('the', 'DET'),
#    ('Croods', 'NOUN'),
#    ('!', '.')]},
#  {'id': 52,
#   'duration': 1053,
#   'text': 'We hunt Kangadillos.',
#   'word_tag': [('We', 'PRON'),
#    ('hunt', 'VERB'),
#    ('Kangadillos', 'NOUN'),
#    ('.', '.')]},
#  {'id': 53,
#   'duration': 1955,
#   'text': 'We topple trees.',
#   'word_tag': [('We', 'PRON'),
#    ('topple', 'VERB'),
#    ('trees', 'NOUN'),
#    ('.', '.')]},
#  {'id': 54,
#   'duration': 1985,
#   'text': 'We paint the things we do on rocks.',
#   'word_tag': [('We', 'PRON'),
#    ('paint', 'VERB'),
#    ('the', 'DET'),
#    ('things', 'NOUN'),
#    ('we', 'PRON'),
#    ('do', 'VERB'),
#    ('on', 'ADP'),
#    ('rocks', 'NOUN'),
#    ('.', '.')]},
#  {'id': 55,
#   'duration': 2001,
#   'text': 'We gotta have a purpose on this farm.',
#   'word_tag': [('We', 'PRON'),
#    ('got', 'VERB'),
#    ('ta', 'NOUN'),
#    ('have', 'VERB'),
#    ('a', 'DET'),
#    ('purpose', 'NOUN'),
#    ('on', 'ADP'),
#    ('this', 'DET'),
#    ('farm', 'NOUN'),
#    ('.', '.')]},
#  {'id': 56,
#   'duration': 3048,
#   'text': "Because, if we don't, we're as useless as a slugopotamus.",
#   'word_tag': [('Because', 'ADP'),
#    (',', '.'),
#    ('if', 'ADP'),
#    ('we', 'PRON'),
#    ('do', 'VERB'),
#    ("n't", 'ADV'),
#    (',', '.'),
#    ('we', 'PRON'),
#    ("'re", 'VERB'),
#    ('as', 'ADV'),
#    ('useless', 'ADJ'),
#    ('as', 'ADP'),
#    ('a', 'DET'),
#    ('slugopotamus', 'NOUN'),
#    ('.', '.')]},
#  {'id': 57,
#   'duration': -51032,
#   'text': "And the Croods aren't slugopotomuses.",
#   'word_tag': [('And', 'CONJ'),
#    ('the', 'DET'),
#    ('Croods', 'NOUN'),
#    ('are', 'VERB'),
#    ("n't", 'ADV'),
#    ('slugopotomuses', 'NOUN'),
#    ('.', '.')]},
#  {'id': 58,
#   'duration': 1015,
#   'text': '‐ As far as we know.',
#   'word_tag': [('‐', 'NOUN'),
#    ('As', 'ADV'),
#    ('far', 'ADV'),
#    ('as', 'ADP'),
#    ('we', 'PRON'),
#    ('know', 'VERB'),
#    ('.', '.')]},
#  {'id': 59,
#   'duration': 2023,
#   'text': '‐ Is doing nothing really so bad?',
#   'word_tag': [('‐', 'NOUN'),
#    ('Is', 'VERB'),
#    ('doing', 'VERB'),
#    ('nothing', 'NOUN'),
#    ('really', 'ADV'),
#    ('so', 'ADV'),
#    ('bad', 'ADJ'),
#    ('?', '.')]},
#  {'id': 60,
#   'duration': 1950,
#   'text': 'Look how happy Douglas is.',
#   'word_tag': [('Look', 'VERB'),
#    ('how', 'ADV'),
#    ('happy', 'ADJ'),
#    ('Douglas', 'NOUN'),
#    ('is', 'VERB'),
#    ('.', '.')]},
#  {'id': 61,
#   'duration': 2981,
#   'text': "See? I've always said moving is overrated.",
#   'word_tag': [('See', 'VERB'),
#    ('?', '.'),
#    ('I', 'PRON'),
#    ("'ve", 'VERB'),
#    ('always', 'ADV'),
#    ('said', 'VERB'),
#    ('moving', 'NOUN'),
#    ('is', 'VERB'),
#    ('overrated', 'VERB'),
#    ('.', '.')]},
#  {'id': 62,
#   'duration': 3069,
#   'text': 'Oh, uh, could someone move my cup closer to my mouth?',
#   'word_tag': [('Oh', 'X'),
#    (',', '.'),
#    ('uh', 'X'),
#    (',', '.'),
#    ('could', 'VERB'),
#    ('someone', 'NOUN'),
#    ('move', 'VERB'),
#    ('my', 'PRON'),
#    ('cup', 'NOUN'),
#    ('closer', 'NOUN'),
#    ('to', 'PRT'),
#    ('my', 'PRON'),
#    ('mouth', 'NOUN'),
#    ('?', '.')]},
#  {'id': 63,
#   'duration': 1931,
#   'text': "‐ Thunk's right.",
#   'word_tag': [('‐', 'ADJ'),
#    ('Thunk', 'NOUN'),
#    ("'s", 'PRT'),
#    ('right', 'NOUN'),
#    ('.', '.')]},
#  {'id': 64,
#   'duration': 1043,
#   'text': 'Down time has an upside.',
#   'word_tag': [('Down', 'NOUN'),
#    ('time', 'NOUN'),
#    ('has', 'VERB'),
#    ('an', 'DET'),
#    ('upside', 'NOUN'),
#    ('.', '.')]},
#  {'id': 65,
#   'duration': 2937,
#   'text': 'More time for stolen kisses.',
#   'word_tag': [('More', 'ADJ'),
#    ('time', 'NOUN'),
#    ('for', 'ADP'),
#    ('stolen', 'ADJ'),
#    ('kisses', 'NOUN'),
#    ('.', '.')]},
#  {'id': 66,
#   'duration': 1017,
#   'text': '‐ Morning, Guy.',
#   'word_tag': [('‐', 'ADJ'),
#    ('Morning', 'NOUN'),
#    (',', '.'),
#    ('Guy', 'NOUN'),
#    ('.', '.')]},
#  {'id': 67,
#   'duration': 2998,
#   'text': '‐ More time for careless whispers. Whoops.',
#   'word_tag': [('‐', 'ADV'),
#    ('More', 'ADJ'),
#    ('time', 'NOUN'),
#    ('for', 'ADP'),
#    ('careless', 'ADJ'),
#    ('whispers', 'NOUN'),
#    ('.', '.'),
#    ('Whoops', 'NOUN'),
#    ('.', '.')]},
#  {'id': 68,
#   'duration': 1993,
#   'text': '‐ Hmm. More time for cuddling.',
#   'word_tag': [('‐', 'ADJ'),
#    ('Hmm', 'NOUN'),
#    ('.', '.'),
#    ('More', 'ADJ'),
#    ('time', 'NOUN'),
#    ('for', 'ADP'),
#    ('cuddling', 'VERB'),
#    ('.', '.')]},
#  {'id': 69,
#   'duration': 1951,
#   'text': '‐ No. No time for cuddling.',
#   'word_tag': [('‐', 'ADJ'),
#    ('No', 'NOUN'),
#    ('.', '.'),
#    ('No', 'DET'),
#    ('time', 'NOUN'),
#    ('for', 'ADP'),
#    ('cuddling', 'VERB'),
#    ('.', '.')]},
#  {'id': 70,
#   'duration': 1048,
#   'text': '‐ Wh... What about the sleep pile?',
#   'word_tag': [('‐', 'NOUN'),
#    ('Wh', 'NOUN'),
#    ('...', '.'),
#    ('What', 'PRON'),
#    ('about', 'ADP'),
#    ('the', 'DET'),
#    ('sleep', 'NOUN'),
#    ('pile', 'NOUN'),
#    ('?', '.')]},
#  {'id': 71,
#   'duration': 1982,
#   'text': 'We did that every night in our old life.',
#   'word_tag': [('We', 'PRON'),
#    ('did', 'VERB'),
#    ('that', 'ADP'),
#    ('every', 'DET'),
#    ('night', 'NOUN'),
#    ('in', 'ADP'),
#    ('our', 'PRON'),
#    ('old', 'ADJ'),
#    ('life', 'NOUN'),
#    ('.', '.')]},
#  {'id': 72,
#   'duration': 1031,
#   'text': "‐ That's family cuddling.",
#   'word_tag': [('‐', 'NOUN'),
#    ('That', 'DET'),
#    ("'s", 'VERB'),
#    ('family', 'NOUN'),
#    ('cuddling', 'NOUN'),
#    ('.', '.')]},
#  {'id': 73,
#   'duration': 1010,
#   'text': "It's completely different.",
#   'word_tag': [('It', 'PRON'),
#    ("'s", 'VERB'),
#    ('completely', 'ADV'),
#    ('different', 'ADJ'),
#    ('.', '.')]},
#  {'id': 74,
#   'duration': 3035,
#   'text': '‐ Fine. New Eep and Guy can cuddle with our eyes.',
#   'word_tag': [('‐', 'ADJ'),
#    ('Fine', 'NOUN'),
#    ('.', '.'),
#    ('New', 'NOUN'),
#    ('Eep', 'NOUN'),
#    ('and', 'CONJ'),
#    ('Guy', 'NOUN'),
#    ('can', 'VERB'),
#    ('cuddle', 'VERB'),
#    ('with', 'ADP'),
#    ('our', 'PRON'),
#    ('eyes', 'NOUN'),
#    ('.', '.')]},
#  {'id': 75,
#   'duration': 1935,
#   'text': '‐ Hey. ‐ Hey.',
#   'word_tag': [('‐', 'NOUN'),
#    ('Hey', 'NOUN'),
#    ('.', '.'),
#    ('‐', 'NOUN'),
#    ('Hey', 'NOUN'),
#    ('.', '.')]},
#  {'id': 76,
#   'duration': 1010,
#   'text': '‐ Hey!',
#   'word_tag': [('‐', 'NOUN'), ('Hey', 'NOUN'), ('!', '.')]},
#  {'id': 77,
#   'duration': 2026,
#   'text': '‐ Hey! Something to do just ran by.',
#   'word_tag': [('‐', 'NOUN'),
#    ('Hey', 'NOUN'),
#    ('!', '.'),
#    ('Something', 'VERB'),
#    ('to', 'PRT'),
#    ('do', 'VERB'),
#    ('just', 'ADV'),
#    ('ran', 'VERB'),
#    ('by', 'ADP'),
#    ('.', '.')]},
#  {'id': 78,
#   'duration': 957,
#   'text': "Mom's right.",
#   'word_tag': [('Mom', 'NOUN'), ("'s", 'PRT'), ('right', 'NOUN'), ('.', '.')]},
#  {'id': 79,
#   'duration': 1015,
#   'text': 'Pigator on the loose.',
#   'word_tag': [('Pigator', 'NOUN'),
#    ('on', 'ADP'),
#    ('the', 'DET'),
#    ('loose', 'NOUN'),
#    ('.', '.')]},
#  {'id': 80,
#   'duration': 2018,
#   'text': "‐ Let's grab it and stab it!",
#   'word_tag': [('‐', 'ADJ'),
#    ('Let', 'NOUN'),
#    ("'s", 'PRT'),
#    ('grab', 'NOUN'),
#    ('it', 'PRON'),
#    ('and', 'CONJ'),
#    ('stab', 'VERB'),
#    ('it', 'PRON'),
#    ('!', '.')]},
#  {'id': 81,
#   'duration': 3998,
#   'text': '‐ Or, we can redirect that stabbing energy into something less stabby.',
#   'word_tag': [('‐', 'NOUN'),
#    ('Or', 'CONJ'),
#    (',', '.'),
#    ('we', 'PRON'),
#    ('can', 'VERB'),
#    ('redirect', 'VERB'),
#    ('that', 'ADP'),
#    ('stabbing', 'VERB'),
#    ('energy', 'NOUN'),
#    ('into', 'ADP'),
#    ('something', 'NOUN'),
#    ('less', 'ADJ'),
#    ('stabby', 'NOUN'),
#    ('.', '.')]},
#  {'id': 82,
#   'duration': -50022,
#   'text': "‐ Uh, I'm still waiting for someone to move my cup. Yeah.",
#   'word_tag': [('‐', 'NOUN'),
#    ('Uh', 'NOUN'),
#    (',', '.'),
#    ('I', 'PRON'),
#    ("'m", 'VERB'),
#    ('still', 'ADV'),
#    ('waiting', 'VERB'),
#    ('for', 'ADP'),
#    ('someone', 'NOUN'),
#    ('to', 'PRT'),
#    ('move', 'VERB'),
#    ('my', 'PRON'),
#    ('cup', 'NOUN'),
#    ('.', '.'),
#    ('Yeah', 'X'),
#    ('.', '.')]},
#  {'id': 83,
#   'duration': 1000,
#   'text': '‐ Ooh!',
#   'word_tag': [('‐', 'ADJ'), ('Ooh', 'NOUN'), ('!', '.')]},
#  {'id': 84,
#   'duration': 1089,
#   'text': '‐ Aw!',
#   'word_tag': [('‐', 'ADJ'), ('Aw', 'NOUN'), ('!', '.')]},
#  {'id': 85,
#   'duration': 985,
#   'text': 'Morning, Phil.',
#   'word_tag': [('Morning', 'NOUN'), (',', '.'), ('Phil', 'NOUN'), ('.', '.')]},
#  {'id': 86,
#   'duration': 1001,
#   'text': '‐ Good morning.',
#   'word_tag': [('‐', 'ADV'),
#    ('Good', 'ADJ'),
#    ('morning', 'NOUN'),
#    ('.', '.')]},
#  {'id': 87,
#   'duration': 1982,
#   'text': 'Just testing my new trap.',
#   'word_tag': [('Just', 'ADV'),
#    ('testing', 'VERB'),
#    ('my', 'PRON'),
#    ('new', 'ADJ'),
#    ('trap', 'NOUN'),
#    ('.', '.')]},
#  {'id': 88,
#   'duration': 2944,
#   'text': 'So no more runaway pigators.',
#   'word_tag': [('So', 'ADV'),
#    ('no', 'ADV'),
#    ('more', 'ADJ'),
#    ('runaway', 'ADJ'),
#    ('pigators', 'NOUN'),
#    ('.', '.')]},
#  {'id': 89,
#   'duration': 1990,
#   'text': '‐ But we were gonna catch that pigator.',
#   'word_tag': [('‐', 'NOUN'),
#    ('But', 'CONJ'),
#    ('we', 'PRON'),
#    ('were', 'VERB'),
#    ('gon', 'VERB'),
#    ('na', 'PRT'),
#    ('catch', 'VERB'),
#    ('that', 'DET'),
#    ('pigator', 'NOUN'),
#    ('.', '.')]},
#  {'id': 90,
#   'duration': 2027,
#   'text': '‐ No need. This trap is flawless.',
#   'word_tag': [('‐', 'NOUN'),
#    ('No', 'DET'),
#    ('need', 'NOUN'),
#    ('.', '.'),
#    ('This', 'DET'),
#    ('trap', 'NOUN'),
#    ('is', 'VERB'),
#    ('flawless', 'ADJ'),
#    ('.', '.')]},
#  {'id': 91,
#   'duration': 2031,
#   'text': 'Just like the rest of the system that runs this farm.',
#   'word_tag': [('Just', 'ADV'),
#    ('like', 'ADP'),
#    ('the', 'DET'),
#    ('rest', 'NOUN'),
#    ('of', 'ADP'),
#    ('the', 'DET'),
#    ('system', 'NOUN'),
#    ('that', 'DET'),
#    ('runs', 'VERB'),
#    ('this', 'DET'),
#    ('farm', 'NOUN'),
#    ('.', '.')]},
#  {'id': 92,
#   'duration': 2943,
#   'text': 'So keep doing nothing, Croods.',
#   'word_tag': [('So', 'ADV'),
#    ('keep', 'ADJ'),
#    ('doing', 'VERB'),
#    ('nothing', 'NOUN'),
#    (',', '.'),
#    ('Croods', 'NOUN'),
#    ('.', '.')]},
#  {'id': 93,
#   'duration': 1060,
#   'text': 'It suits you.',
#   'word_tag': [('It', 'PRON'),
#    ('suits', 'NOUN'),
#    ('you', 'PRON'),
#    ('.', '.')]},
#  {'id': 94,
#   'duration': 964,
#   'text': '‐ What was that?',
#   'word_tag': [('‐', 'VERB'),
#    ('What', 'PRON'),
#    ('was', 'VERB'),
#    ('that', 'DET'),
#    ('?', '.')]},
#  {'id': 95,
#   'duration': 1972,
#   'text': "‐ Oh, that's a bounceberry.",
#   'word_tag': [('‐', 'NOUN'),
#    ('Oh', 'X'),
#    (',', '.'),
#    ('that', 'DET'),
#    ("'s", 'VERB'),
#    ('a', 'DET'),
#    ('bounceberry', 'NOUN'),
#    ('.', '.')]},
#  {'id': 96,
#   'duration': 1057,
#   'text': "They're ripe. It's time to harvest them.",
#   'word_tag': [('They', 'PRON'),
#    ("'re", 'VERB'),
#    ('ripe', 'ADJ'),
#    ('.', '.'),
#    ('It', 'PRON'),
#    ("'s", 'VERB'),
#    ('time', 'NOUN'),
#    ('to', 'PRT'),
#    ('harvest', 'VERB'),
#    ('them', 'PRON'),
#    ('.', '.')]},
#  {'id': 97,
#   'duration': 1926,
#   'text': "‐ Ooh! Uh, we'll do that!",
#   'word_tag': [('‐', 'ADJ'),
#    ('Ooh', 'NOUN'),
#    ('!', '.'),
#    ('Uh', 'NOUN'),
#    (',', '.'),
#    ('we', 'PRON'),
#    ("'ll", 'VERB'),
#    ('do', 'VERB'),
#    ('that', 'DET'),
#    ('!', '.')]},
#  {'id': 98,
#   'duration': 1052,
#   'text': "‐ Oh, I don't think so.",
#   'word_tag': [('‐', 'NOUN'),
#    ('Oh', 'NOUN'),
#    (',', '.'),
#    ('I', 'PRON'),
#    ('do', 'VERB'),
#    ("n't", 'ADV'),
#    ('think', 'VERB'),
#    ('so', 'ADV'),
#    ('.', '.')]},
#  {'id': 99,
#   'duration': -51044,
#   'text': 'Bounceberries are a favorite fruit around here.',
#   'word_tag': [('Bounceberries', 'NOUN'),
#    ('are', 'VERB'),
#    ('a', 'DET'),
#    ('favorite', 'ADJ'),
#    ('fruit', 'NOUN'),
#    ('around', 'ADP'),
#    ('here', 'ADV'),
#    ('.', '.')]},
#  {'id': 100,
#   'duration': 2055,
#   'text': 'And they can be tricky. Even dangerous.',
#   'word_tag': [('And', 'CONJ'),
#    ('they', 'PRON'),
#    ('can', 'VERB'),
#    ('be', 'VERB'),
#    ('tricky', 'ADJ'),
#    ('.', '.'),
#    ('Even', 'ADV'),
#    ('dangerous', 'ADJ'),
#    ('.', '.')]},
#  {'id': 101,
#   'duration': 1998,
#   'text': "‐ Great! We love danger. We're in.",
#   'word_tag': [('‐', 'ADV'),
#    ('Great', 'NOUN'),
#    ('!', '.'),
#    ('We', 'PRON'),
#    ('love', 'VERB'),
#    ('danger', 'ADV'),
#    ('.', '.'),
#    ('We', 'PRON'),
#    ("'re", 'VERB'),
#    ('in', 'ADP'),
#    ('.', '.')]},
#  {'id': 102,
#   'duration': 1959,
#   'text': "‐ You're out. It's taken care of.",
#   'word_tag': [('‐', 'NOUN'),
#    ('You', 'PRON'),
#    ("'re", 'VERB'),
#    ('out', 'PRT'),
#    ('.', '.'),
#    ('It', 'PRON'),
#    ("'s", 'VERB'),
#    ('taken', 'VERB'),
#    ('care', 'NOUN'),
#    ('of', 'ADP'),
#    ('.', '.')]},
#  {'id': 103,
#   'duration': 2035,
#   'text': '‐ Uh, let me guess. By the system?',
#   'word_tag': [('‐', 'NOUN'),
#    ('Uh', 'NOUN'),
#    (',', '.'),
#    ('let', 'VERB'),
#    ('me', 'PRON'),
#    ('guess', 'VERB'),
#    ('.', '.'),
#    ('By', 'ADP'),
#    ('the', 'DET'),
#    ('system', 'NOUN'),
#    ('?', '.')]},
#  {'id': 104,
#   'duration': 2957,
#   'text': '‐ Precisely. With me at the helm.',
#   'word_tag': [('‐', 'NOUN'),
#    ('Precisely', 'ADV'),
#    ('.', '.'),
#    ('With', 'ADP'),
#    ('me', 'PRON'),
#    ('at', 'ADP'),
#    ('the', 'DET'),
#    ('helm', 'NOUN'),
#    ('.', '.')]},
#  {'id': 105,
#   'duration': 3969,
#   'text': "So, if you'll excuse me, I need to limber up before the harvest.",
#   'word_tag': [('So', 'ADV'),
#    (',', '.'),
#    ('if', 'ADP'),
#    ('you', 'PRON'),
#    ("'ll", 'VERB'),
#    ('excuse', 'VERB'),
#    ('me', 'PRON'),
#    (',', '.'),
#    ('I', 'PRON'),
#    ('need', 'VERB'),
#    ('to', 'PRT'),
#    ('limber', 'VERB'),
#    ('up', 'PRT'),
#    ('before', 'ADP'),
#    ('the', 'DET'),
#    ('harvest', 'NOUN'),
#    ('.', '.')]},
#  {'id': 106,
#   'duration': 2071,
#   'text': 'Time for a steam in the man cave.',
#   'word_tag': [('Time', 'NOUN'),
#    ('for', 'ADP'),
#    ('a', 'DET'),
#    ('steam', 'NOUN'),
#    ('in', 'ADP'),
#    ('the', 'DET'),
#    ('man', 'NOUN'),
#    ('cave', 'NOUN'),
#    ('.', '.')]},
#  {'id': 107,
#   'duration': 994,
#   'text': '‐ Come on.',
#   'word_tag': [('‐', 'ADJ'), ('Come', 'NOUN'), ('on', 'ADP'), ('.', '.')]},
#  {'id': 108,
#   'duration': 2952,
#   'text': 'There has to be something we can do around here',
#   'word_tag': [('There', 'DET'),
#    ('has', 'VERB'),
#    ('to', 'PRT'),
#    ('be', 'VERB'),
#    ('something', 'NOUN'),
#    ('we', 'PRON'),
#    ('can', 'VERB'),
#    ('do', 'VERB'),
#    ('around', 'ADV'),
#    ('here', 'ADV')]},
#  {'id': 109,
#   'duration': 1997,
#   'text': '‐ You know who has ideas?',
#   'word_tag': [('‐', 'NOUN'),
#    ('You', 'PRON'),
#    ('know', 'VERB'),
#    ('who', 'PRON'),
#    ('has', 'VERB'),
#    ('ideas', 'NOUN'),
#    ('?', '.')]},
#  {'id': 110,
#   'duration': 2043,
#   'text': 'Guy‐Boy, I can hear those wheels turning.',
#   'word_tag': [('Guy‐Boy', 'NOUN'),
#    (',', '.'),
#    ('I', 'PRON'),
#    ('can', 'VERB'),
#    ('hear', 'VERB'),
#    ('those', 'DET'),
#    ('wheels', 'NOUN'),
#    ('turning', 'VERB'),
#    ('.', '.')]},
#  {'id': 111,
#   'duration': 1948,
#   'text': '‐ You get one pet name a day.',
#   'word_tag': [('‐', 'NOUN'),
#    ('You', 'PRON'),
#    ('get', 'VERB'),
#    ('one', 'NUM'),
#    ('pet', 'NOUN'),
#    ('name', 'NOUN'),
#    ('a', 'DET'),
#    ('day', 'NOUN'),
#    ('.', '.')]},
#  {'id': 112,
#   'duration': 1068,
#   'text': "So that's it. You're done.",
#   'word_tag': [('So', 'ADP'),
#    ('that', 'DET'),
#    ("'s", 'VERB'),
#    ('it', 'PRON'),
#    ('.', '.'),
#    ('You', 'PRON'),
#    ("'re", 'VERB'),
#    ('done', 'VERB'),
#    ('.', '.')]},
#  {'id': 113,
#   'duration': 3915,
#   'text': '‐ Well, one idea is both sides compromise and live in peace.',
#   'word_tag': [('‐', 'ADV'),
#    ('Well', 'ADV'),
#    (',', '.'),
#    ('one', 'NUM'),
#    ('idea', 'NOUN'),
#    ('is', 'VERB'),
#    ('both', 'DET'),
#    ('sides', 'NOUN'),
#    ('compromise', 'NOUN'),
#    ('and', 'CONJ'),
#    ('live', 'VERB'),
#    ('in', 'ADP'),
#    ('peace', 'NOUN'),
#    ('.', '.')]},
#  {'id': 114,
#   'duration': 1068,
#   'text': "‐ Ha. That'll never work.",
#   'word_tag': [('‐', 'ADJ'),
#    ('Ha', 'NOUN'),
#    ('.', '.'),
#    ('That', 'DET'),
#    ("'ll", 'VERB'),
#    ('never', 'ADV'),
#    ('work', 'VERB'),
#    ('.', '.')]},
#  {'id': 115,
#   'duration': 2931,
#   'text': '‐ You just need something to do to be happy.',
#   'word_tag': [('‐', 'NOUN'),
#    ('You', 'PRON'),
#    ('just', 'ADV'),
#    ('need', 'VERB'),
#    ('something', 'NOUN'),
#    ('to', 'PRT'),
#    ('do', 'VERB'),
#    ('to', 'PRT'),
#    ('be', 'VERB'),
#    ('happy', 'ADJ'),
#    ('.', '.')]},
#  {'id': 116,
#   'duration': 2010,
#   'text': "But it doesn't have to be work, right?",
#   'word_tag': [('But', 'CONJ'),
#    ('it', 'PRON'),
#    ('does', 'VERB'),
#    ("n't", 'ADV'),
#    ('have', 'VERB'),
#    ('to', 'PRT'),
#    ('be', 'VERB'),
#    ('work', 'NOUN'),
#    (',', '.'),
#    ('right', 'ADV'),
#    ('?', '.')]},
#  {'id': 117,
#   'duration': 1010,
#   'text': 'So, how about a game?',
#   'word_tag': [('So', 'ADV'),
#    (',', '.'),
#    ('how', 'ADV'),
#    ('about', 'ADP'),
#    ('a', 'DET'),
#    ('game', 'NOUN'),
#    ('?', '.')]},
#  {'id': 118,
#   'duration': 1027,
#   'text': 'Ooh. How about this,',
#   'word_tag': [('Ooh', 'NOUN'),
#    ('.', '.'),
#    ('How', 'ADV'),
#    ('about', 'ADP'),
#    ('this', 'DET'),
#    (',', '.')]},
#  {'id': 119,
#   'duration': 2028,
#   'text': 'you find something and then you throw it?',
#   'word_tag': [('you', 'PRON'),
#    ('find', 'VERB'),
#    ('something', 'NOUN'),
#    ('and', 'CONJ'),
#    ('then', 'ADV'),
#    ('you', 'PRON'),
#    ('throw', 'VERB'),
#    ('it', 'PRON'),
#    ('?', '.')]},
#  {'id': 120,
#   'duration': 1012,
#   'text': 'It\'s called "Throw."',
#   'word_tag': [('It', 'PRON'),
#    ("'s", 'VERB'),
#    ('called', 'VERB'),
#    ('``', '.'),
#    ('Throw', 'NOUN'),
#    ('.', '.'),
#    ("''", '.')]},
#  {'id': 121,
#   'duration': 1986,
#   'text': 'Yeah. Throw might need some work.',
#   'word_tag': [('Yeah', 'X'),
#    ('.', '.'),
#    ('Throw', 'VERB'),
#    ('might', 'VERB'),
#    ('need', 'VERB'),
#    ('some', 'DET'),
#    ('work', 'NOUN'),
#    ('.', '.')]},
#  {'id': 122,
#   'duration': 1006,
#   'text': '‐ Better idea,',
#   'word_tag': [('‐', 'ADV'),
#    ('Better', 'NOUN'),
#    ('idea', 'NOUN'),
#    (',', '.')]},
#  {'id': 123,
#   'duration': 1994,
#   'text': 'we stop doing what Phil and Hope tell us to do',
#   'word_tag': [('we', 'PRON'),
#    ('stop', 'VERB'),
#    ('doing', 'VERB'),
#    ('what', 'PRON'),
#    ('Phil', 'NOUN'),
#    ('and', 'CONJ'),
#    ('Hope', 'NOUN'),
#    ('tell', 'VERB'),
#    ('us', 'PRON'),
#    ('to', 'PRT'),
#    ('do', 'VERB')]},
#  {'id': 124,
#   'duration': 1077,
#   'text': 'and we start doing what we wanna do.',
#   'word_tag': [('and', 'CONJ'),
#    ('we', 'PRON'),
#    ('start', 'VERB'),
#    ('doing', 'VERB'),
#    ('what', 'PRON'),
#    ('we', 'PRON'),
#    ('wan', 'VERB'),
#    ('na', 'ADV'),
#    ('do', 'VERB'),
#    ('.', '.')]},
#  {'id': 125,
#   'duration': 1922,
#   'text': 'Because this is our home now.',
#   'word_tag': [('Because', 'ADP'),
#    ('this', 'DET'),
#    ('is', 'VERB'),
#    ('our', 'PRON'),
#    ('home', 'NOUN'),
#    ('now', 'ADV'),
#    ('.', '.')]},
#  {'id': 126,
#   'duration': 65,
#   'text': '‐ Yes.',
#   'word_tag': [('‐', 'ADJ'), ('Yes', 'NOUN'), ('.', '.')]},
#  {'id': 127,
#   'duration': -51082,
#   'text': "‐ Grug, go tell Phil that's what's happening.",
#   'word_tag': [('‐', 'ADJ'),
#    ('Grug', 'NOUN'),
#    (',', '.'),
#    ('go', 'VERB'),
#    ('tell', 'ADV'),
#    ('Phil', 'NOUN'),
#    ('that', 'DET'),
#    ("'s", 'VERB'),
#    ('what', 'PRON'),
#    ("'s", 'VERB'),
#    ('happening', 'VERB'),
#    ('.', '.')]},
#  {'id': 128,
#   'duration': 1056,
#   'text': '‐ Aw, in the steam?',
#   'word_tag': [('‐', 'NOUN'),
#    ('Aw', 'NOUN'),
#    (',', '.'),
#    ('in', 'ADP'),
#    ('the', 'DET'),
#    ('steam', 'NOUN'),
#    ('?', '.')]},
#  {'id': 129,
#   'duration': 2944,
#   'text': "‐ Yes. And I'll tell Hope I'm gonna help her.",
#   'word_tag': [('‐', 'ADJ'),
#    ('Yes', 'NOUN'),
#    ('.', '.'),
#    ('And', 'CONJ'),
#    ('I', 'PRON'),
#    ("'ll", 'VERB'),
#    ('tell', 'VERB'),
#    ('Hope', 'NOUN'),
#    ('I', 'PRON'),
#    ("'m", 'VERB'),
#    ('gon', 'VERB'),
#    ('na', 'PRT'),
#    ('help', 'VERB'),
#    ('her', 'PRON'),
#    ('.', '.')]},
#  {'id': 130,
#   'duration': 1006,
#   'text': 'Whether she likes it or not.',
#   'word_tag': [('Whether', 'ADP'),
#    ('she', 'PRON'),
#    ('likes', 'VERB'),
#    ('it', 'PRON'),
#    ('or', 'CONJ'),
#    ('not', 'ADV'),
#    ('.', '.')]},
#  {'id': 131,
#   'duration': 1048,
#   'text': '‐ Dawn will love this.',
#   'word_tag': [('‐', 'ADJ'),
#    ('Dawn', 'NOUN'),
#    ('will', 'VERB'),
#    ('love', 'VERB'),
#    ('this', 'DET'),
#    ('.', '.')]},
#  {'id': 132,
#   'duration': 2960,
#   'text': 'Her whole life, her parents have been so worried about her getting hurt,',
#   'word_tag': [('Her', 'PRON'),
#    ('whole', 'ADJ'),
#    ('life', 'NOUN'),
#    (',', '.'),
#    ('her', 'PRON'),
#    ('parents', 'NOUN'),
#    ('have', 'VERB'),
#    ('been', 'VERB'),
#    ('so', 'ADV'),
#    ('worried', 'ADJ'),
#    ('about', 'ADP'),
#    ('her', 'PRON'),
#    ('getting', 'VERB'),
#    ('hurt', 'NOUN'),
#    (',', '.')]},
#  {'id': 133,
#   'duration': 1056,
#   'text': "they've never let her do anything.",
#   'word_tag': [('they', 'PRON'),
#    ("'ve", 'VERB'),
#    ('never', 'ADV'),
#    ('let', 'VERB'),
#    ('her', 'PRON'),
#    ('do', 'VERB'),
#    ('anything', 'NOUN'),
#    ('.', '.')]},
#  {'id': 134,
#   'duration': 1939,
#   'text': "Let's go, Guy‐baby.",
#   'word_tag': [('Let', 'VERB'),
#    ("'s", 'PRT'),
#    ('go', 'VERB'),
#    (',', '.'),
#    ('Guy‐baby', 'NOUN'),
#    ('.', '.')]},
#  {'id': 135,
#   'duration': 2034,
#   'text': "‐ One pet name a day. That's two.",
#   'word_tag': [('‐', 'VERB'),
#    ('One', 'NUM'),
#    ('pet', 'NOUN'),
#    ('name', 'NOUN'),
#    ('a', 'DET'),
#    ('day', 'NOUN'),
#    ('.', '.'),
#    ('That', 'DET'),
#    ("'s", 'VERB'),
#    ('two', 'NUM'),
#    ('.', '.')]},
#  {'id': 136,
#   'duration': 3048,
#   'text': "‐ You're always welcome in my man cave, Grug.",
#   'word_tag': [('‐', 'NOUN'),
#    ('You', 'PRON'),
#    ("'re", 'VERB'),
#    ('always', 'ADV'),
#    ('welcome', 'ADJ'),
#    ('in', 'ADP'),
#    ('my', 'PRON'),
#    ('man', 'NOUN'),
#    ('cave', 'NOUN'),
#    (',', '.'),
#    ('Grug', 'NOUN'),
#    ('.', '.')]},
#  {'id': 137,
#   'duration': 2940,
#   'text': 'My steam is your steam.',
#   'word_tag': [('My', 'PRON'),
#    ('steam', 'NOUN'),
#    ('is', 'VERB'),
#    ('your', 'PRON'),
#    ('steam', 'NOUN'),
#    ('.', '.')]},
#  {'id': 138,
#   'duration': 1023,
#   'text': '‐ Uh, yeah, thanks.',
#   'word_tag': [('‐', 'NOUN'),
#    ('Uh', 'NOUN'),
#    (',', '.'),
#    ('yeah', 'X'),
#    (',', '.'),
#    ('thanks', 'NOUN'),
#    ('.', '.')]},
#  {'id': 139,
#   'duration': 1967,
#   'text': "So I'm here to tell you‐‐",
#   'word_tag': [('So', 'ADV'),
#    ('I', 'PRON'),
#    ("'m", 'VERB'),
#    ('here', 'ADV'),
#    ('to', 'PRT'),
#    ('tell', 'VERB'),
#    ('you‐‐', 'NOUN')]},
#  {'id': 140,
#   'duration': 1005,
#   'text': "So I'm here to‐‐",
#   'word_tag': [('So', 'ADV'),
#    ('I', 'PRON'),
#    ("'m", 'VERB'),
#    ('here', 'ADV'),
#    ('to‐‐', 'NOUN')]},
#  {'id': 141,
#   'duration': 1992,
#   'text': "I'm here to tell you things‐‐",
#   'word_tag': [('I', 'PRON'),
#    ("'m", 'VERB'),
#    ('here', 'ADV'),
#    ('to', 'PRT'),
#    ('tell', 'VERB'),
#    ('you', 'PRON'),
#    ('things‐‐', 'VERB')]},
#  {'id': 142,
#   'duration': 1052,
#   'text': 'are going to change around here.',
#   'word_tag': [('are', 'VERB'),
#    ('going', 'VERB'),
#    ('to', 'PRT'),
#    ('change', 'VERB'),
#    ('around', 'ADP'),
#    ('here', 'ADV'),
#    ('.', '.')]},
#  {'id': 143,
#   'duration': 1019,
#   'text': '‐ Of course.',
#   'word_tag': [('‐', 'NOUN'), ('Of', 'ADP'), ('course', 'NOUN'), ('.', '.')]},
#  {'id': 144,
#   'duration': 1948,
#   'text': "Let's talk about that.",
#   'word_tag': [('Let', 'VERB'),
#    ("'s", 'PRT'),
#    ('talk', 'VERB'),
#    ('about', 'ADP'),
#    ('that', 'DET'),
#    ('.', '.')]},
#  {'id': 145,
#   'duration': 1959,
#   'text': "‐ Great, so we're gonna‐‐",
#   'word_tag': [('‐', 'ADV'),
#    ('Great', 'NOUN'),
#    (',', '.'),
#    ('so', 'ADP'),
#    ('we', 'PRON'),
#    ("'re", 'VERB'),
#    ('gon', 'VERB'),
#    ('na', 'PRT'),
#    ('‐‐', 'VERB')]},
#  {'id': 146,
#   'duration': 1052,
#   'text': '‐ After the steam.',
#   'word_tag': [('‐', 'NOUN'),
#    ('After', 'ADP'),
#    ('the', 'DET'),
#    ('steam', 'NOUN'),
#    ('.', '.')]},
#  {'id': 147,
#   'duration': 1031,
#   'text': '‐ Right, but‐but Ugga said‐‐',
#   'word_tag': [('‐', 'ADV'),
#    ('Right', 'NOUN'),
#    (',', '.'),
#    ('but‐but', 'NOUN'),
#    ('Ugga', 'NOUN'),
#    ('said‐‐', 'NOUN')]},
#  {'id': 148,
#   'duration': 1969,
#   'text': '‐ Steam first, talk after.',
#   'word_tag': [('‐', 'NOUN'),
#    ('Steam', 'NOUN'),
#    ('first', 'ADV'),
#    (',', '.'),
#    ('talk', 'NOUN'),
#    ('after', 'ADP'),
#    ('.', '.')]},
#  {'id': 149,
#   'duration': -52053,
#   'text': "‐ Okay, but, uh, I'm‐‐",
#   'word_tag': [('‐', 'NOUN'),
#    ('Okay', 'NOUN'),
#    (',', '.'),
#    ('but', 'CONJ'),
#    (',', '.'),
#    ('uh', 'X'),
#    (',', '.'),
#    ("I'm‐‐", 'NOUN')]},
#  {'id': 150,
#   'duration': 1985,
#   'text': '‐ Steam, then talk.',
#   'word_tag': [('‐', 'ADJ'),
#    ('Steam', 'NOUN'),
#    (',', '.'),
#    ('then', 'ADV'),
#    ('talk', 'NOUN'),
#    ('.', '.')]},
#  {'id': 151,
#   'duration': 52,
#   'text': '‐ But‐‐',
#   'word_tag': [('‐', 'NOUN'), ('But‐‐', 'NOUN')]},
#  {'id': 152,
#   'duration': 1004,
#   'text': '‐ Steam, talk.',
#   'word_tag': [('‐', 'ADJ'),
#    ('Steam', 'NOUN'),
#    (',', '.'),
#    ('talk', 'NOUN'),
#    ('.', '.')]},
#  {'id': 153,
#   'duration': 2008,
#   'text': '‐ Well, how long of a steam?',
#   'word_tag': [('‐', 'ADV'),
#    ('Well', 'ADV'),
#    (',', '.'),
#    ('how', 'ADV'),
#    ('long', 'ADV'),
#    ('of', 'ADP'),
#    ('a', 'DET'),
#    ('steam', 'NOUN'),
#    ('?', '.')]},
#  {'id': 154,
#   'duration': 994,
#   'text': 'Phil?',
#   'word_tag': [('Phil', 'NOUN'), ('?', '.')]},
#  {'id': 155,
#   'duration': 1977,
#   'text': 'Phil? Phil?',
#   'word_tag': [('Phil', 'NOUN'), ('?', '.'), ('Phil', 'NOUN'), ('?', '.')]},
#  {'id': 156,
#   'duration': 1048,
#   'text': "Phil, where'd you go? Phil!",
#   'word_tag': [('Phil', 'NOUN'),
#    (',', '.'),
#    ('where', 'ADV'),
#    ("'d", 'VERB'),
#    ('you', 'PRON'),
#    ('go', 'VERB'),
#    ('?', '.'),
#    ('Phil', 'NOUN'),
#    ('!', '.')]},
#  {'id': 157,
#   'duration': 1007,
#   'text': '‐ Yes?',
#   'word_tag': [('‐', 'VERB'), ('Yes', 'X'), ('?', '.')]},
#  {'id': 158,
#   'duration': 3950,
#   'text': "See? You're completely relaxed, thanks to the steam.",
#   'word_tag': [('See', 'VERB'),
#    ('?', '.'),
#    ('You', 'PRON'),
#    ("'re", 'VERB'),
#    ('completely', 'ADV'),
#    ('relaxed', 'ADJ'),
#    (',', '.'),
#    ('thanks', 'NOUN'),
#    ('to', 'PRT'),
#    ('the', 'DET'),
#    ('steam', 'NOUN'),
#    ('.', '.')]},
#  {'id': 159,
#   'duration': 1951,
#   'text': '‐ So sweet of you to offer.',
#   'word_tag': [('‐', 'NOUN'),
#    ('So', 'NOUN'),
#    ('sweet', 'NOUN'),
#    ('of', 'ADP'),
#    ('you', 'PRON'),
#    ('to', 'PRT'),
#    ('offer', 'VERB'),
#    ('.', '.')]},
#  {'id': 160,
#   'duration': 2002,
#   'text': "But I'm making lunch. Okay?",
#   'word_tag': [('But', 'CONJ'),
#    ('I', 'PRON'),
#    ("'m", 'VERB'),
#    ('making', 'VERB'),
#    ('lunch', 'NOUN'),
#    ('.', '.'),
#    ('Okay', 'NOUN'),
#    ('?', '.')]},
#  {'id': 161,
#   'duration': 2057,
#   'text': "‐ No. We're making lunch. Together.",
#   'word_tag': [('‐', 'ADJ'),
#    ('No', 'NOUN'),
#    ('.', '.'),
#    ('We', 'PRON'),
#    ("'re", 'VERB'),
#    ('making', 'VERB'),
#    ('lunch', 'NOUN'),
#    ('.', '.'),
#    ('Together', 'ADV'),
#    ('.', '.')]},
#  {'id': 162,
#   'duration': 3914,
#   'text': '‐ Ohh. You wanna help make lunch?',
#   'word_tag': [('‐', 'ADJ'),
#    ('Ohh', 'NOUN'),
#    ('.', '.'),
#    ('You', 'PRON'),
#    ('wan', 'VERB'),
#    ('na', 'PRT'),
#    ('help', 'VERB'),
#    ('make', 'VERB'),
#    ('lunch', 'NOUN'),
#    ('?', '.')]},
#  {'id': 163,
#   'duration': 989,
#   'text': 'In my kitchen?',
#   'word_tag': [('In', 'ADP'),
#    ('my', 'PRON'),
#    ('kitchen', 'NOUN'),
#    ('?', '.')]},
#  {'id': 164,
#   'duration': 1000,
#   'text': '‐ Our kitchen.',
#   'word_tag': [('‐', 'VERB'),
#    ('Our', 'PRON'),
#    ('kitchen', 'NOUN'),
#    ('.', '.')]},
#  {'id': 165,
#   'duration': 2939,
#   'text': '‐ Of course. Our kitchen.',
#   'word_tag': [('‐', 'NOUN'),
#    ('Of', 'ADP'),
#    ('course', 'NOUN'),
#    ('.', '.'),
#    ('Our', 'PRON'),
#    ('kitchen', 'NOUN'),
#    ('.', '.')]},
#  {'id': 166,
#   'duration': 1043,
#   'text': 'Because you live here now.',
#   'word_tag': [('Because', 'ADP'),
#    ('you', 'PRON'),
#    ('live', 'VERB'),
#    ('here', 'ADV'),
#    ('now', 'ADV'),
#    ('.', '.')]},
#  {'id': 167,
#   'duration': 2973,
#   'text': 'So we share the kitchen, that was once mine. Good.',
#   'word_tag': [('So', 'ADP'),
#    ('we', 'PRON'),
#    ('share', 'NOUN'),
#    ('the', 'DET'),
#    ('kitchen', 'NOUN'),
#    (',', '.'),
#    ('that', 'DET'),
#    ('was', 'VERB'),
#    ('once', 'ADV'),
#    ('mine', 'ADJ'),
#    ('.', '.'),
#    ('Good', 'ADJ'),
#    ('.', '.')]},
#  {'id': 168,
#   'duration': 1012,
#   'text': "‐ I'm glad you're not upset.",
#   'word_tag': [('‐', 'NOUN'),
#    ('I', 'PRON'),
#    ("'m", 'VERB'),
#    ('glad', 'ADJ'),
#    ('you', 'PRON'),
#    ("'re", 'VERB'),
#    ('not', 'ADV'),
#    ('upset', 'VERB'),
#    ('.', '.')]},
#  {'id': 169,
#   'duration': 998,
#   'text': '‐ Upset?',
#   'word_tag': [('‐', 'NOUN'), ('Upset', 'NOUN'), ('?', '.')]},
#  {'id': 170,
#   'duration': 1994,
#   'text': 'In the kitchen I helped build from nothing',
#   'word_tag': [('In', 'ADP'),
#    ('the', 'DET'),
#    ('kitchen', 'NOUN'),
#    ('I', 'PRON'),
#    ('helped', 'VERB'),
#    ('build', 'VERB'),
#    ('from', 'ADP'),
#    ('nothing', 'NOUN')]},
#  {'id': 171,
#   'duration': 2952,
#   'text': 'that I never had to share with anyone before now?',
#   'word_tag': [('that', 'ADP'),
#    ('I', 'PRON'),
#    ('never', 'ADV'),
#    ('had', 'VERB'),
#    ('to', 'PRT'),
#    ('share', 'NOUN'),
#    ('with', 'ADP'),
#    ('anyone', 'NOUN'),
#    ('before', 'ADV'),
#    ('now', 'ADV'),
#    ('?', '.')]},
#  {'id': 172,
#   'duration': 2984,
#   'text': "How could I be upset? That's crazy.",
#   'word_tag': [('How', 'ADV'),
#    ('could', 'VERB'),
#    ('I', 'PRON'),
#    ('be', 'VERB'),
#    ('upset', 'VERB'),
#    ('?', '.'),
#    ('That', 'DET'),
#    ("'s", 'VERB'),
#    ('crazy', 'ADJ'),
#    ('.', '.')]},
#  {'id': 173,
#   'duration': 1977,
#   'text': "‐ We're cooking meat, right?",
#   'word_tag': [('‐', 'NOUN'),
#    ('We', 'PRON'),
#    ("'re", 'VERB'),
#    ('cooking', 'VERB'),
#    ('meat', 'NOUN'),
#    (',', '.'),
#    ('right', 'ADV'),
#    ('?', '.')]},
#  {'id': 174,
#   'duration': -51014,
#   'text': "Because that's all I eat. Meat.",
#   'word_tag': [('Because', 'ADP'),
#    ('that', 'DET'),
#    ("'s", 'VERB'),
#    ('all', 'DET'),
#    ('I', 'PRON'),
#    ('eat', 'VERB'),
#    ('.', '.'),
#    ('Meat', 'NOUN'),
#    ('.', '.')]},
#  {'id': 175,
#   'duration': 2023,
#   'text': '‐ Oh, good. More help.',
#   'word_tag': [('‐', 'NOUN'),
#    ('Oh', 'NOUN'),
#    (',', '.'),
#    ('good', 'ADJ'),
#    ('.', '.'),
#    ('More', 'ADJ'),
#    ('help', 'NOUN'),
#    ('.', '.')]},
#  {'id': 176,
#   'duration': 2948,
#   'text': "Well, we're making soup, so‐‐",
#   'word_tag': [('Well', 'ADV'),
#    (',', '.'),
#    ('we', 'PRON'),
#    ("'re", 'VERB'),
#    ('making', 'VERB'),
#    ('soup', 'NOUN'),
#    (',', '.'),
#    ('so‐‐', 'NOUN')]},
#  {'id': 177,
#   'duration': 1055,
#   'text': '‐ Soup? You got it.',
#   'word_tag': [('‐', 'NOUN'),
#    ('Soup', 'NOUN'),
#    ('?', '.'),
#    ('You', 'PRON'),
#    ('got', 'VERB'),
#    ('it', 'PRON'),
#    ('.', '.')]},
#  {'id': 178,
#   'duration': 2994,
#   'text': "‐ So you don't know what soup is.",
#   'word_tag': [('‐', 'NOUN'),
#    ('So', 'ADV'),
#    ('you', 'PRON'),
#    ('do', 'VERB'),
#    ("n't", 'ADV'),
#    ('know', 'VERB'),
#    ('what', 'PRON'),
#    ('soup', 'NOUN'),
#    ('is', 'VERB'),
#    ('.', '.')]},
#  {'id': 179,
#   'duration': 1004,
#   'text': '‐ Nope.',
#   'word_tag': [('‐', 'ADJ'), ('Nope', 'NOUN'), ('.', '.')]},
#  {'id': 180,
#   'duration': 1025,
#   'text': '‐ Ew.',
#   'word_tag': [('‐', 'ADJ'), ('Ew', 'NOUN'), ('.', '.')]},
#  {'id': 181,
#   'duration': 2008,
#   'text': "‐ You're saying we're gonna do something around here?",
#   'word_tag': [('‐', 'NOUN'),
#    ('You', 'PRON'),
#    ("'re", 'VERB'),
#    ('saying', 'VERB'),
#    ('we', 'PRON'),
#    ("'re", 'VERB'),
#    ('gon', 'VERB'),
#    ('na', 'PRT'),
#    ('do', 'VERB'),
#    ('something', 'NOUN'),
#    ('around', 'ADP'),
#    ('here', 'ADV'),
#    ('?', '.')]},
#  {'id': 182,
#   'duration': 2006,
#   'text': "But my parents don't want me doing anything.",
#   'word_tag': [('But', 'CONJ'),
#    ('my', 'PRON'),
#    ('parents', 'NOUN'),
#    ('do', 'VERB'),
#    ("n't", 'ADV'),
#    ('want', 'VERB'),
#    ('me', 'PRON'),
#    ('doing', 'VERB'),
#    ('anything', 'NOUN'),
#    ('.', '.')]},
#  {'id': 183,
#   'duration': 1955,
#   'text': 'Even playing Throw like this.',
#   'word_tag': [('Even', 'ADV'),
#    ('playing', 'VERB'),
#    ('Throw', 'NOUN'),
#    ('like', 'ADP'),
#    ('this', 'DET'),
#    ('.', '.')]},
#  {'id': 184,
#   'duration': 997,
#   'text': "'Cause they think I'll die.",
#   'word_tag': [("'Cause", 'ADP'),
#    ('they', 'PRON'),
#    ('think', 'VERB'),
#    ('I', 'PRON'),
#    ("'ll", 'VERB'),
#    ('die', 'VERB'),
#    ('.', '.')]},
#  {'id': 185,
#   'duration': 1073,
#   'text': "‐ I'm so glad you guys like Throw.",
#   'word_tag': [('‐', 'NOUN'),
#    ('I', 'PRON'),
#    ("'m", 'VERB'),
#    ('so', 'ADV'),
#    ('glad', 'ADJ'),
#    ('you', 'PRON'),
#    ('guys', 'VERB'),
#    ('like', 'ADP'),
#    ('Throw', 'NOUN'),
#    ('.', '.')]},
#  {'id': 186,
#   'duration': 1955,
#   'text': '‐ Forget your parents.',
#   'word_tag': [('‐', 'ADJ'),
#    ('Forget', 'NOUN'),
#    ('your', 'PRON'),
#    ('parents', 'NOUN'),
#    ('.', '.')]},
#  {'id': 187,
#   'duration': 1988,
#   'text': "Because we're not gonna do anything.",
#   'word_tag': [('Because', 'ADP'),
#    ('we', 'PRON'),
#    ("'re", 'VERB'),
#    ('not', 'ADV'),
#    ('gon', 'VERB'),
#    ('na', 'PRT'),
#    ('do', 'VERB'),
#    ('anything', 'NOUN'),
#    ('.', '.')]},
#  {'id': 188,
#   'duration': 2910,
#   'text': "We're gonna do everything.",
#   'word_tag': [('We', 'PRON'),
#    ("'re", 'VERB'),
#    ('gon', 'VERB'),
#    ('na', 'PRT'),
#    ('do', 'VERB'),
#    ('everything', 'NOUN'),
#    ('.', '.')]},
#  {'id': 189,
#   'duration': 1060,
#   'text': 'Whoa, game changer.',
#   'word_tag': [('Whoa', 'NOUN'),
#    (',', '.'),
#    ('game', 'NOUN'),
#    ('changer', 'NOUN'),
#    ('.', '.')]},
#  {'id': 190,
#   'duration': 2977,
#   'text': "You're saying I could eat breakfast for dinner?",
#   'word_tag': [('You', 'PRON'),
#    ("'re", 'VERB'),
#    ('saying', 'VERB'),
#    ('I', 'PRON'),
#    ('could', 'VERB'),
#    ('eat', 'VERB'),
#    ('breakfast', 'NOUN'),
#    ('for', 'ADP'),
#    ('dinner', 'NOUN'),
#    ('?', '.')]},
#  {'id': 191,
#   'duration': 2002,
#   'text': 'I could get dirty and stay dirty?',
#   'word_tag': [('I', 'PRON'),
#    ('could', 'VERB'),
#    ('get', 'VERB'),
#    ('dirty', 'ADJ'),
#    ('and', 'CONJ'),
#    ('stay', 'VERB'),
#    ('dirty', 'ADV'),
#    ('?', '.')]},
#  {'id': 192,
#   'duration': 1969,
#   'text': 'I could tell my parents what to do?',
#   'word_tag': [('I', 'PRON'),
#    ('could', 'VERB'),
#    ('tell', 'VERB'),
#    ('my', 'PRON'),
#    ('parents', 'NOUN'),
#    ('what', 'PRON'),
#    ('to', 'PRT'),
#    ('do', 'VERB'),
#    ('?', '.')]},
#  {'id': 193,
#   'duration': 2002,
#   'text': "‐ Exactly. And that's just the start.",
#   'word_tag': [('‐', 'ADV'),
#    ('Exactly', 'ADV'),
#    ('.', '.'),
#    ('And', 'CONJ'),
#    ('that', 'DET'),
#    ("'s", 'VERB'),
#    ('just', 'ADV'),
#    ('the', 'DET'),
#    ('start', 'NOUN'),
#    ('.', '.')]},
#  {'id': 194,
#   'duration': 1048,
#   'text': '‐ Breakfast‐dinner? The best.',
#   'word_tag': [('‐', 'NOUN'),
#    ('Breakfast‐dinner', 'NOUN'),
#    ('?', '.'),
#    ('The', 'DET'),
#    ('best', 'ADJ'),
#    ('.', '.')]},
#  {'id': 195,
#   'duration': 1943,
#   'text': 'Dirt? Never gets old.',
#   'word_tag': [('Dirt', 'NOUN'),
#    ('?', '.'),
#    ('Never', 'NOUN'),
#    ('gets', 'VERB'),
#    ('old', 'ADJ'),
#    ('.', '.')]},
#  {'id': 196,
#   'duration': 2022,
#   'text': 'But I think your parents like to be in charge.',
#   'word_tag': [('But', 'CONJ'),
#    ('I', 'PRON'),
#    ('think', 'VERB'),
#    ('your', 'PRON'),
#    ('parents', 'NOUN'),
#    ('like', 'ADP'),
#    ('to', 'PRT'),
#    ('be', 'VERB'),
#    ('in', 'ADP'),
#    ('charge', 'NOUN'),
#    ('.', '.')]},
#  {'id': 197,
#   'duration': 2043,
#   'text': "It's their thing. So maybe we start smaller.",
#   'word_tag': [('It', 'PRON'),
#    ("'s", 'VERB'),
#    ('their', 'PRON'),
#    ('thing', 'NOUN'),
#    ('.', '.'),
#    ('So', 'ADV'),
#    ('maybe', 'ADV'),
#    ('we', 'PRON'),
#    ('start', 'VERB'),
#    ('smaller', 'ADJ'),
#    ('.', '.')]},
#  {'id': 198,
#   'duration': 982,
#   'text': '‐ Smaller how?',
#   'word_tag': [('‐', 'ADV'), ('Smaller', 'NOUN'), ('how', 'ADV'), ('?', '.')]},
#  {'id': 199,
#   'duration': -50069,
#   'text': '‐ Well, what if we added something to Throw, like catching?',
#   'word_tag': [('‐', 'ADV'),
#    ('Well', 'ADV'),
#    (',', '.'),
#    ('what', 'PRON'),
#    ('if', 'ADP'),
#    ('we', 'PRON'),
#    ('added', 'VERB'),
#    ('something', 'NOUN'),
#    ('to', 'PRT'),
#    ('Throw', 'VERB'),
#    (',', '.'),
#    ('like', 'ADP'),
#    ('catching', 'VERB'),
#    ('?', '.')]},
#  {'id': 200,
#   'duration': 1073,
#   'text': 'Ooh! We could call it Catch.',
#   'word_tag': [('Ooh', 'ADV'),
#    ('!', '.'),
#    ('We', 'PRON'),
#    ('could', 'VERB'),
#    ('call', 'VERB'),
#    ('it', 'PRON'),
#    ('Catch', 'NOUN'),
#    ('.', '.')]},
#  {'id': 201,
#   'duration': 3010,
#   'text': '‐ Hey, uh, could one of you move my cup closer to my mouth?',
#   'word_tag': [('‐', 'NOUN'),
#    ('Hey', 'NOUN'),
#    (',', '.'),
#    ('uh', 'NOUN'),
#    (',', '.'),
#    ('could', 'VERB'),
#    ('one', 'NUM'),
#    ('of', 'ADP'),
# ...
#    ('one', 'NUM'),
#    ('.', '.'),
#    ('That', 'DET'),
#    ("'s", 'VERB'),
#    ('all', 'DET'),
#    ('.', '.')]},
#  {'id': 450,
#   'duration': 998,
#   'text': 'This means one.',
#   'word_tag': [('This', 'DET'),
#    ('means', 'VERB'),
#    ('one', 'NUM'),
#    ('.', '.')]},
#  {'id': 451,
#   'duration': 1998,
#   'text': '‐ Ooh! Really? This means one?',
#   'word_tag': [('‐', 'ADJ'),
#    ('Ooh', 'NOUN'),
#    ('!', '.'),
#    ('Really', 'ADV'),
#    ('?', '.'),
#    ('This', 'DET'),
#    ('means', 'VERB'),
#    ('one', 'NUM'),
#    ('?', '.')]},
#  {'id': 452,
#   'duration': 1057,
#   'text': '‐ No. That means thirsty.',
#   'word_tag': [('‐', 'ADJ'),
#    ('No', 'NOUN'),
#    ('.', '.'),
#    ('That', 'DET'),
#    ('means', 'VERB'),
#    ('thirsty', 'ADJ'),
#    ('.', '.')]},
#  {'id': 453,
#   'duration': 998,
#   'text': 'This means one.',
#   'word_tag': [('This', 'DET'),
#    ('means', 'VERB'),
#    ('one', 'NUM'),
#    ('.', '.')]},
#  {'id': 454,
#   'duration': 956,
#   'text': '‐ This?',
#   'word_tag': [('‐', 'NOUN'), ('This', 'DET'), ('?', '.')]},
#  {'id': 455,
#   'duration': 1011,
#   'text': '‐ No. This!',
#   'word_tag': [('‐', 'ADJ'),
#    ('No', 'DET'),
#    ('.', '.'),
#    ('This', 'DET'),
#    ('!', '.')]},
#  {'id': 456,
#   'duration': 1979,
#   'text': '‐ Oh. Thanks for clearing that up.',
#   'word_tag': [('‐', 'ADJ'),
#    ('Oh', 'NOUN'),
#    ('.', '.'),
#    ('Thanks', 'NOUN'),
#    ('for', 'ADP'),
#    ('clearing', 'VERB'),
#    ('that', 'DET'),
#    ('up', 'PRT'),
#    ('.', '.')]},
#  {'id': 457,
#   'duration': 1965,
#   'text': 'What are they saying now?',
#   'word_tag': [('What', 'PRON'),
#    ('are', 'VERB'),
#    ('they', 'PRON'),
#    ('saying', 'VERB'),
#    ('now', 'ADV'),
#    ('?', '.')]},
#  {'id': 458,
#   'duration': 2040,
#   'text': "‐ They feel misled. So they're gonna take all our food.",
#   'word_tag': [('‐', 'ADP'),
#    ('They', 'PRON'),
#    ('feel', 'VERB'),
#    ('misled', 'VERB'),
#    ('.', '.'),
#    ('So', 'ADP'),
#    ('they', 'PRON'),
#    ("'re", 'VERB'),
#    ('gon', 'VERB'),
#    ('na', 'NOUN'),
#    ('take', 'VERB'),
#    ('all', 'DET'),
#    ('our', 'PRON'),
#    ('food', 'NOUN'),
#    ('.', '.')]},
#  {'id': 459,
#   'duration': 2919,
#   'text': 'Right after they trash the farm to teach you a little lesson',
#   'word_tag': [('Right', 'ADV'),
#    ('after', 'ADP'),
#    ('they', 'PRON'),
#    ('trash', 'VERB'),
#    ('the', 'DET'),
#    ('farm', 'NOUN'),
#    ('to', 'PRT'),
#    ('teach', 'VERB'),
#    ('you', 'PRON'),
#    ('a', 'DET'),
#    ('little', 'ADJ'),
#    ('lesson', 'NOUN')]},
#  {'id': 460,
#   'duration': 1044,
#   'text': 'in honesty and integrity.',
#   'word_tag': [('in', 'ADP'),
#    ('honesty', 'NOUN'),
#    ('and', 'CONJ'),
#    ('integrity', 'NOUN'),
#    ('.', '.')]},
#  {'id': 461,
#   'duration': 1015,
#   'text': '‐ They said all that with punches?',
#   'word_tag': [('‐', 'NOUN'),
#    ('They', 'PRON'),
#    ('said', 'VERB'),
#    ('all', 'DET'),
#    ('that', 'ADP'),
#    ('with', 'ADP'),
#    ('punches', 'NOUN'),
#    ('?', '.')]},
#  {'id': 462,
#   'duration': 1940,
#   'text': "‐ It's a rich, mysterious language.",
#   'word_tag': [('‐', 'ADP'),
#    ('It', 'PRON'),
#    ("'s", 'VERB'),
#    ('a', 'DET'),
#    ('rich', 'ADJ'),
#    (',', '.'),
#    ('mysterious', 'ADJ'),
#    ('language', 'NOUN'),
#    ('.', '.')]},
#  {'id': 463,
#   'duration': 4002,
#   'text': '‐ So, Croods, you still want to help with the bounceberry harvest, yes?',
#   'word_tag': [('‐', 'NOUN'),
#    ('So', 'ADV'),
#    (',', '.'),
#    ('Croods', 'NOUN'),
#    (',', '.'),
#    ('you', 'PRON'),
#    ('still', 'ADV'),
#    ('want', 'VERB'),
#    ('to', 'PRT'),
#    ('help', 'VERB'),
#    ('with', 'ADP'),
#    ('the', 'DET'),
#    ('bounceberry', 'NOUN'),
#    ('harvest', 'NOUN'),
#    (',', '.'),
#    ('yes', 'X'),
#    ('?', '.')]},
#  {'id': 464,
#   'duration': 1948,
#   'text': '‐ By stopping the punch monkeys?',
#   'word_tag': [('‐', 'NOUN'),
#    ('By', 'ADP'),
#    ('stopping', 'VERB'),
#    ('the', 'DET'),
#    ('punch', 'NOUN'),
#    ('monkeys', 'NOUN'),
#    ('?', '.')]},
#  {'id': 465,
#   'duration': 1005,
#   'text': '‐ And fixing your mistake?',
#   'word_tag': [('‐', 'NOUN'),
#    ('And', 'CONJ'),
#    ('fixing', 'VERB'),
#    ('your', 'PRON'),
#    ('mistake', 'NOUN'),
#    ('?', '.')]},
#  {'id': 466,
#   'duration': 1052,
#   'text': "‐ Oh, I wouldn't put it like that.",
#   'word_tag': [('‐', 'NOUN'),
#    ('Oh', 'NOUN'),
#    (',', '.'),
#    ('I', 'PRON'),
#    ('would', 'VERB'),
#    ("n't", 'ADV'),
#    ('put', 'VERB'),
#    ('it', 'PRON'),
#    ('like', 'ADP'),
#    ('that', 'DET'),
#    ('.', '.')]},
#  {'id': 467,
#   'duration': 1043,
#   'text': "‐ I would. That's exactly it.",
#   'word_tag': [('‐', 'NOUN'),
#    ('I', 'PRON'),
#    ('would', 'VERB'),
#    ('.', '.'),
#    ('That', 'DET'),
#    ("'s", 'VERB'),
#    ('exactly', 'ADV'),
#    ('it', 'PRON'),
#    ('.', '.')]},
#  {'id': 468,
#   'duration': 989,
#   'text': "‐ We're on it.",
#   'word_tag': [('‐', 'NOUN'),
#    ('We', 'PRON'),
#    ("'re", 'VERB'),
#    ('on', 'ADP'),
#    ('it', 'PRON'),
#    ('.', '.')]},
#  {'id': 469,
#   'duration': 2031,
#   'text': "‐ And I'm all over it because this is how I roll now!",
#   'word_tag': [('‐', 'NOUN'),
#    ('And', 'CONJ'),
#    ('I', 'PRON'),
#    ("'m", 'VERB'),
#    ('all', 'DET'),
#    ('over', 'ADP'),
#    ('it', 'PRON'),
#    ('because', 'ADP'),
#    ('this', 'DET'),
#    ('is', 'VERB'),
#    ('how', 'ADV'),
#    ('I', 'PRON'),
#    ('roll', 'VERB'),
#    ('now', 'ADV'),
#    ('!', '.')]},
#  {'id': 470,
#   'duration': 2984,
#   'text': 'All Dawn, no rules, so deal with it!',
#   'word_tag': [('All', 'DET'),
#    ('Dawn', 'NOUN'),
#    (',', '.'),
#    ('no', 'DET'),
#    ('rules', 'NOUN'),
#    (',', '.'),
#    ('so', 'ADV'),
#    ('deal', 'ADJ'),
#    ('with', 'ADP'),
#    ('it', 'PRON'),
#    ('!', '.')]},
#  {'id': 471,
#   'duration': 969,
#   'text': '‐ Same team, Dawn.',
#   'word_tag': [('‐', 'ADJ'),
#    ('Same', 'NOUN'),
#    ('team', 'NOUN'),
#    (',', '.'),
#    ('Dawn', 'NOUN'),
#    ('.', '.')]},
#  {'id': 472,
#   'duration': 2969,
#   'text': '‐ Yeah. The Kill Team!',
#   'word_tag': [('‐', 'ADJ'),
#    ('Yeah', 'NOUN'),
#    ('.', '.'),
#    ('The', 'DET'),
#    ('Kill', 'NOUN'),
#    ('Team', 'NOUN'),
#    ('!', '.')]},
#  {'id': 473,
#   'duration': 1018,
#   'text': '‐ Uh, no.',
#   'word_tag': [('‐', 'NOUN'),
#    ('Uh', 'NOUN'),
#    (',', '.'),
#    ('no', 'DET'),
#    ('.', '.')]},
#  {'id': 474,
#   'duration': 1052,
#   'text': 'No killing necessary.',
#   'word_tag': [('No', 'DET'),
#    ('killing', 'VERB'),
#    ('necessary', 'ADJ'),
#    ('.', '.')]},
#  {'id': 475,
#   'duration': 990,
#   'text': "Here's the plan‐‐",
#   'word_tag': [('Here', 'ADV'),
#    ("'s", 'VERB'),
#    ('the', 'DET'),
#    ('plan‐‐', 'NOUN')]},
#  {'id': 476,
#   'duration': 3010,
#   'text': '‐ No offense, but your plan is why we need a new plan.',
#   'word_tag': [('‐', 'ADJ'),
#    ('No', 'NOUN'),
#    ('offense', 'NOUN'),
#    (',', '.'),
#    ('but', 'CONJ'),
#    ('your', 'PRON'),
#    ('plan', 'NOUN'),
#    ('is', 'VERB'),
#    ('why', 'ADV'),
#    ('we', 'PRON'),
#    ('need', 'VERB'),
#    ('a', 'DET'),
#    ('new', 'ADJ'),
#    ('plan', 'NOUN'),
#    ('.', '.')]},
#  {'id': 477,
#   'duration': 1968,
#   'text': "‐ Right. So here's the plan.",
#   'word_tag': [('‐', 'ADV'),
#    ('Right', 'NOUN'),
#    ('.', '.'),
#    ('So', 'ADV'),
#    ('here', 'ADV'),
#    ("'s", 'VERB'),
#    ('the', 'DET'),
#    ('plan', 'NOUN'),
#    ('.', '.')]},
#  {'id': 478,
#   'duration': 2002,
#   'text': 'Hey, punch monkeys!',
#   'word_tag': [('Hey', 'NOUN'),
#    (',', '.'),
#    ('punch', 'ADJ'),
#    ('monkeys', 'NOUN'),
#    ('!', '.')]},
#  {'id': 479,
#   'duration': 1965,
#   'text': 'You forgot the bounceberries.',
#   'word_tag': [('You', 'PRON'),
#    ('forgot', 'VERB'),
#    ('the', 'DET'),
#    ('bounceberries', 'NOUN'),
#    ('.', '.')]},
#  {'id': 480,
#   'duration': 1039,
#   'text': '‐ So we brought you a bunch.',
#   'word_tag': [('‐', 'NOUN'),
#    ('So', 'ADP'),
#    ('we', 'PRON'),
#    ('brought', 'VERB'),
#    ('you', 'PRON'),
#    ('a', 'DET'),
#    ('bunch', 'NOUN'),
#    ('.', '.')]},
#  {'id': 481,
#   'duration': 1000,
#   'text': '‐ To go.',
#   'word_tag': [('‐', 'NOUN'), ('To', 'PRT'), ('go', 'VERB'), ('.', '.')]},
#  {'id': 482,
#   'duration': 3027,
#   'text': 'Look at us, working together, bouncing together.',
#   'word_tag': [('Look', 'NOUN'),
#    ('at', 'ADP'),
#    ('us', 'PRON'),
#    (',', '.'),
#    ('working', 'VERB'),
#    ('together', 'ADV'),
#    (',', '.'),
#    ('bouncing', 'VERB'),
#    ('together', 'ADV'),
#    ('.', '.')]},
#  {'id': 483,
#   'duration': 1018,
#   'text': 'This is a real moment.',
#   'word_tag': [('This', 'DET'),
#    ('is', 'VERB'),
#    ('a', 'DET'),
#    ('real', 'ADJ'),
#    ('moment', 'NOUN'),
#    ('.', '.')]},
#  {'id': 484,
#   'duration': 1026,
#   'text': 'Whoo‐‐',
#   'word_tag': [('Whoo‐‐', 'NOUN')]},
#  {'id': 485,
#   'duration': 1943,
#   'text': 'Woo‐hoo!',
#   'word_tag': [('Woo‐hoo', 'NOUN'), ('!', '.')]},
#  {'id': 486,
#   'duration': 1018,
#   'text': 'Whoa!',
#   'word_tag': [('Whoa', 'NOUN'), ('!', '.')]},
#  {'id': 487,
#   'duration': 2031,
#   'text': 'Boy, I am really up here.',
#   'word_tag': [('Boy', 'NOUN'),
#    (',', '.'),
#    ('I', 'PRON'),
#    ('am', 'VERB'),
#    ('really', 'ADV'),
#    ('up', 'ADV'),
#    ('here', 'ADV'),
#    ('.', '.')]},
#  {'id': 488,
#   'duration': -52085,
#   'text': 'Oh, pretty clouds!',
#   'word_tag': [('Oh', 'X'),
#    (',', '.'),
#    ('pretty', 'ADJ'),
#    ('clouds', 'NOUN'),
#    ('!', '.')]},
#  {'id': 489,
#   'duration': 1006,
#   'text': 'That one looks like a pillow.',
#   'word_tag': [('That', 'DET'),
#    ('one', 'NUM'),
#    ('looks', 'VERB'),
#    ('like', 'ADP'),
#    ('a', 'DET'),
#    ('pillow', 'NOUN'),
#    ('.', '.')]},
#  {'id': 490,
#   'duration': 2018,
#   'text': "And there's an egg, a coconut, Thunk,",
#   'word_tag': [('And', 'CONJ'),
#    ('there', 'DET'),
#    ("'s", 'VERB'),
#    ('an', 'DET'),
#    ('egg', 'NOUN'),
#    (',', '.'),
#    ('a', 'DET'),
#    ('coconut', 'NOUN'),
#    (',', '.'),
#    ('Thunk', 'NOUN'),
#    (',', '.')]},
#  {'id': 491,
#   'duration': 1047,
#   'text': 'a‐a‐and going down.',
#   'word_tag': [('a‐a‐and', 'NOUN'),
#    ('going', 'VERB'),
#    ('down', 'PRT'),
#    ('.', '.')]},
#  {'id': 492,
#   'duration': 1922,
#   'text': 'Whoo!',
#   'word_tag': [('Whoo', 'NOUN'), ('!', '.')]},
#  {'id': 493,
#   'duration': 1027,
#   'text': 'Going back up.',
#   'word_tag': [('Going', 'VERB'), ('back', 'ADV'), ('up', 'ADV'), ('.', '.')]},
#  {'id': 494,
#   'duration': 2002,
#   'text': 'Oh, yeah!',
#   'word_tag': [('Oh', 'X'), (',', '.'), ('yeah', 'X'), ('!', '.')]},
#  {'id': 495,
#   'duration': 1029,
#   'text': '‐ Guy.',
#   'word_tag': [('‐', 'ADJ'), ('Guy', 'NOUN'), ('.', '.')]},
#  {'id': 496,
#   'duration': 1973,
#   'text': '‐ Hey, no bounce‐frogging.',
#   'word_tag': [('‐', 'NOUN'),
#    ('Hey', 'NOUN'),
#    (',', '.'),
#    ('no', 'DET'),
#    ('bounce‐frogging', 'NOUN'),
#    ('.', '.')]},
#  {'id': 497,
#   'duration': 1079,
#   'text': 'This is serious monkey business.',
#   'word_tag': [('This', 'DET'),
#    ('is', 'VERB'),
#    ('serious', 'ADJ'),
#    ('monkey', 'NOUN'),
#    ('business', 'NOUN'),
#    ('.', '.')]},
#  {'id': 498,
#   'duration': 3977,
#   'text': "‐ It's time to chew and shoo these monkeys outta here.",
#   'word_tag': [('‐', 'ADP'),
#    ('It', 'PRON'),
#    ("'s", 'VERB'),
#    ('time', 'NOUN'),
#    ('to', 'PRT'),
#    ('chew', 'VERB'),
#    ('and', 'CONJ'),
#    ('shoo', 'VERB'),
#    ('these', 'DET'),
#    ('monkeys', 'NOUN'),
#    ('outta', 'VERB'),
#    ('here', 'ADV'),
#    ('.', '.')]},
#  {'id': 499,
#   'duration': 1971,
#   'text': 'Everyone, chew!',
#   'word_tag': [('Everyone', 'NOUN'),
#    (',', '.'),
#    ('chew', 'NOUN'),
#    ('!', '.')]},
#  {'id': 500,
#   'duration': 1955,
#   'text': 'And shoo!',
#   'word_tag': [('And', 'CONJ'), ('shoo', 'NOUN'), ('!', '.')]},
#  {'id': 501,
#   'duration': 1979,
#   'text': 'Abandon berries!',
#   'word_tag': [('Abandon', 'NOUN'), ('berries', 'NOUN'), ('!', '.')]},
#  {'id': 502,
#   'duration': 1000,
#   'text': 'Gotcha!',
#   'word_tag': [('Gotcha', 'NOUN'), ('!', '.')]},
#  {'id': 503,
#   'duration': 1996,
#   'text': "Phil and Hope, you're up!",
#   'word_tag': [('Phil', 'NOUN'),
#    ('and', 'CONJ'),
#    ('Hope', 'NOUN'),
#    (',', '.'),
#    ('you', 'PRON'),
#    ("'re", 'VERB'),
#    ('up', 'PRT'),
#    ('!', '.')]},
#  {'id': 504,
#   'duration': 3023,
#   'text': "‐ And that's how you bounce punch monkeys out the door.",
#   'word_tag': [('‐', 'NOUN'),
#    ('And', 'CONJ'),
#    ('that', 'DET'),
#    ("'s", 'VERB'),
#    ('how', 'ADV'),
#    ('you', 'PRON'),
#    ('bounce', 'VERB'),
#    ('punch', 'ADJ'),
#    ('monkeys', 'NOUN'),
#    ('out', 'PRT'),
#    ('the', 'DET'),
#    ('door', 'NOUN'),
#    ('.', '.')]},
#  {'id': 505,
#   'duration': -50019,
#   'text': '‐ Along with all our bounceberries!',
#   'word_tag': [('‐', 'NOUN'),
#    ('Along', 'ADP'),
#    ('with', 'ADP'),
#    ('all', 'DET'),
#    ('our', 'PRON'),
#    ('bounceberries', 'NOUN'),
#    ('!', '.')]},
#  {'id': 506,
#   'duration': 2071,
#   'text': 'Except for that one. Which you are eating.',
#   'word_tag': [('Except', 'ADP'),
#    ('for', 'ADP'),
#    ('that', 'DET'),
#    ('one', 'NUM'),
#    ('.', '.'),
#    ('Which', 'ADP'),
#    ('you', 'PRON'),
#    ('are', 'VERB'),
#    ('eating', 'VERB'),
#    ('.', '.')]},
#  {'id': 507,
#   'duration': 976,
#   'text': 'Ugh!',
#   'word_tag': [('Ugh', 'NOUN'), ('!', '.')]},
#  {'id': 508,
#   'duration': 2068,
#   'text': '‐ The point is, we did it together.',
#   'word_tag': [('‐', 'VERB'),
#    ('The', 'DET'),
#    ('point', 'NOUN'),
#    ('is', 'VERB'),
#    (',', '.'),
#    ('we', 'PRON'),
#    ('did', 'VERB'),
#    ('it', 'PRON'),
#    ('together', 'ADV'),
#    ('.', '.')]},
#  {'id': 509,
#   'duration': 2999,
#   'text': 'We built a bridge between ourselves and we crossed it.',
#   'word_tag': [('We', 'PRON'),
#    ('built', 'VERB'),
#    ('a', 'DET'),
#    ('bridge', 'NOUN'),
#    ('between', 'ADP'),
#    ('ourselves', 'NOUN'),
#    ('and', 'CONJ'),
#    ('we', 'PRON'),
#    ('crossed', 'VERB'),
#    ('it', 'PRON'),
#    ('.', '.')]},
#  {'id': 510,
#   'duration': 3943,
#   'text': '‐ No. The point is, we found our purpose here.',
#   'word_tag': [('‐', 'ADJ'),
#    ('No', 'NOUN'),
#    ('.', '.'),
#    ('The', 'DET'),
#    ('point', 'NOUN'),
#    ('is', 'VERB'),
#    (',', '.'),
#    ('we', 'PRON'),
#    ('found', 'VERB'),
#    ('our', 'PRON'),
#    ('purpose', 'NOUN'),
#    ('here', 'ADV'),
#    ('.', '.')]},
#  {'id': 511,
#   'duration': 1990,
#   'text': "Fixing Phil's mistakes.",
#   'word_tag': [('Fixing', 'VERB'),
#    ('Phil', 'NOUN'),
#    ("'s", 'PRT'),
#    ('mistakes', 'NOUN'),
#    ('.', '.')]},
#  {'id': 512,
#   'duration': 1027,
#   'text': '‐ Starting with the system.',
#   'word_tag': [('‐', 'NOUN'),
#    ('Starting', 'VERB'),
#    ('with', 'ADP'),
#    ('the', 'DET'),
#    ('system', 'NOUN'),
#    ('.', '.')]},
#  {'id': 513,
#   'duration': 2040,
#   'text': "Yeah, let's crush the system!",
#   'word_tag': [('Yeah', 'X'),
#    (',', '.'),
#    ('let', 'VERB'),
#    ("'s", 'PRT'),
#    ('crush', 'VERB'),
#    ('the', 'DET'),
#    ('system', 'NOUN'),
#    ('!', '.')]},
#  {'id': 514,
#   'duration': 2036,
#   'text': '‐ Ooh. And afterwards maybe we could play Catch.',
#   'word_tag': [('‐', 'ADJ'),
#    ('Ooh', 'NOUN'),
#    ('.', '.'),
#    ('And', 'CONJ'),
#    ('afterwards', 'NOUN'),
#    ('maybe', 'ADV'),
#    ('we', 'PRON'),
#    ('could', 'VERB'),
#    ('play', 'VERB'),
#    ('Catch', 'NOUN'),
#    ('.', '.')]},
#  {'id': 515,
#   'duration': 2030,
#   'text': "‐ No! They'll ruin the system.",
#   'word_tag': [('‐', 'ADJ'),
#    ('No', 'DET'),
#    ('!', '.'),
#    ('They', 'PRON'),
#    ("'ll", 'VERB'),
#    ('ruin', 'VERB'),
#    ('the', 'DET'),
#    ('system', 'NOUN'),
#    ('.', '.')]},
#  {'id': 516,
#   'duration': 1014,
#   'text': '‐ Who cares?',
#   'word_tag': [('‐', 'NOUN'), ('Who', 'PRON'), ('cares', 'VERB'), ('?', '.')]},
#  {'id': 517,
#   'duration': 2997,
#   'text': "If they're busy, I get my kitchen back. So I win.",
#   'word_tag': [('If', 'ADP'),
#    ('they', 'PRON'),
#    ("'re", 'VERB'),
#    ('busy', 'ADJ'),
#    (',', '.'),
#    ('I', 'PRON'),
#    ('get', 'VERB'),
#    ('my', 'PRON'),
#    ('kitchen', 'NOUN'),
#    ('back', 'ADV'),
#    ('.', '.'),
#    ('So', 'ADP'),
#    ('I', 'PRON'),
#    ('win', 'VERB'),
#    ('.', '.')]},
#  {'id': 518,
#   'duration': 1993,
#   'text': 'Which means you win.',
#   'word_tag': [('Which', 'ADJ'),
#    ('means', 'VERB'),
#    ('you', 'PRON'),
#    ('win', 'VERB'),
#    ('.', '.')]},
#  {'id': 519,
#   'duration': 2917,
#   'text': "‐ You're right. High five.",
#   'word_tag': [('‐', 'NOUN'),
#    ('You', 'PRON'),
#    ("'re", 'VERB'),
#    ('right', 'ADJ'),
#    ('.', '.'),
#    ('High', 'ADJ'),
#    ('five', 'NUM'),
#    ('.', '.')]},
#  {'id': 520,
#   'duration': 2004,
#   'text': "‐ And we're stuck.",
#   'word_tag': [('‐', 'NOUN'),
#    ('And', 'CONJ'),
#    ('we', 'PRON'),
#    ("'re", 'VERB'),
#    ('stuck', 'VERB'),
#    ('.', '.')]}]

# %%
with open('subWithWords.json', 'w') as out:
    json.dump(data, out)
